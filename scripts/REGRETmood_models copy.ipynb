# %% [markdown]
# # SWB Computational Models

# %%
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp, pearsonr, spearmanr
import scipy.stats as stats
import pandas as pd
import scipy
from scipy.optimize import least_squares
import sklearn
from sklearn.metrics import r2_score
import random
import os
from statannot import add_stat_annotation
from statsmodels.stats.outliers_influence import variance_inflation_factor
import itertools
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
base_dir  = '/Users/alexandrafink/Documents/GraduateSchool/SaezLab/SWB/'
behav_dir = f'{base_dir}behavior_analysis/'

# %%
import sys
sys.path.append(f'{base_dir}swb_computational_modeling/swb_behav_models/scripts')
from SWB_modeling_utils import *

# %%
# load subj_ids of subj with preprocessed ephys data
subj_ids = pd.read_excel(f'{base_dir}SWB_subjects.xlsx', sheet_name='Usable_Subjects', usecols=[0]).PatientID.tolist()
# find subj without sufficient variation in mood ratings and drop from subj_ids list 
subj_ids = [subj_ids[idx] for idx in np.arange(0,len(subj_ids))[pd.read_excel(f'{base_dir}SWB_subjects.xlsx', sheet_name='Usable_Subjects', usecols=[2]).mood_var.isnull()]]
subj_ids
# Out:
# ['MS002',
#  'MS003',
#  'MS009',
#  'MS011',
#  'MS015',
#  'MS017',
#  'MS019',
#  'MS022',
#  'MS024',
#  'MS025',
#  'MS026',
#  'MS027',
#  'MS029',
#  'MS033',
#  'MS035',
#  'MS041',
#  'MS043',
#  'DA8',
#  'DA023']

# %%
#get swb bdi and bai 
raw_dir = f'{base_dir}behavior_analysis/behavior_raw/'
subj_bdi = []
subj_bai = []
for subj_id in subj_ids:
    raw_data_dir = f'{raw_dir}{subj_id}/'
    raw_data_files = os.listdir(raw_data_dir)
    #load task data
    #load swb bdi and bai info to add to mood df
    raw_bdi_name = [x for x in raw_data_files if 'BDI' in x] #not all subj have BDI
    if raw_bdi_name:
        raw_bdi = pd.read_table(raw_data_dir+raw_bdi_name[0]) 
        bdi = raw_bdi['BDI Score'].iloc[-1]   
    else:
        bdi = 0
    subj_bdi.append(bdi)

    #bai loading (not all subj have BAI)
    raw_bai_name = [x for x in raw_data_files if 'BAI' in x]
    if raw_bai_name:
        raw_bai = pd.read_table(raw_data_dir+raw_bai_name[0]) 
        bai = raw_bai['BAI Score'].iloc[-1]   
    else:
        bai = 0
    subj_bai.append(bai)

# %%
list(zip(subj_ids,subj_bdi))
# Out:
# [('MS002', 14),
#  ('MS003', 8),
#  ('MS009', 16),
#  ('MS011', 13),
#  ('MS015', 26),
#  ('MS017', 26),
#  ('MS019', 12),
#  ('MS022', 10),
#  ('MS024', 16),
#  ('MS025', 10),
#  ('MS026', 9),
#  ('MS027', 22),
#  ('MS029', 32),
#  ('MS033', 39),
#  ('MS035', 15),
#  ('MS041', 10),
#  ('MS043', 23),
#  ('DA8', 13),
#  ('DA023', 14)]

# %%
all_mood = pd.concat([pd.read_csv(f'{behav_dir}behavior_preprocessed/{subj_id}_rate_data').assign(subj_id = subj_id) for subj_id in subj_ids]).reset_index()
all_mood = all_mood[all_mood.Round !=1]
all_mood['t1_round_idx'] = all_mood.Round-1
all_mood['t2_round_idx'] = all_mood.Round-2
all_mood['t3_round_idx'] = all_mood.Round-3
### recompute zscore using scipy function - edit clean behav function later!
all_norm_mood = []
for subj_id in subj_ids:
    all_norm_mood.extend(zscore(all_mood[all_mood.subj_id == subj_id].Rating))

all_mood['norm_mood'] = all_norm_mood
all_mood
# Out:
#      index  Round  Rating  RatingOnset        RT  zscore_mood  bdi  bai  \
# 2        2      4    70.0   539.343131  5.210698     0.320722   14    0
# 3        3      7    70.0   572.673634  3.332630     0.320722   14    0
# 4        4     10    69.0   605.109393  3.499831     0.185132   14    0
# 5        5     13    71.0   638.791836  3.884104     0.456312   14    0
# 6        6     16    71.0   671.977904  4.250371     0.456312   14    0
# ..     ...    ...     ...          ...       ...          ...  ...  ...
# 971     46    139    50.0  1808.030407  0.000618    -1.679568   14    0
# 972     47    142    65.0  1837.135575  3.097746    -0.579509   14    0
# 973     48    145    75.0  1872.784369  3.873045     0.153865   14    0
# 974     49    148    50.0  1904.262850  0.000525    -1.679568   14    0
# 975     50    151    50.0  1930.536959  0.000584    -1.679568   14    0
#
#     subj_id  RatingOnset.1  t1_round_idx  t2_round_idx  t3_round_idx  \
# 2     MS002            NaN             3             2             1
# 3     MS002            NaN             6             5             4
# 4     MS002            NaN             9             8             7
# 5     MS002            NaN            12            11            10
# 6     MS002            NaN            15            14            13
# ..      ...            ...           ...           ...           ...
# 971   DA023            NaN           138           137           136
# 972   DA023            NaN           141           140           139
# 973   DA023            NaN           144           143           142
# 974   DA023            NaN           147           146           145
# 975   DA023            NaN           150           149           148
#
#      norm_mood
# 2     0.277664
# 3     0.277664
# 4     0.134538
# 5     0.420789
# 6     0.420789
# ..         ...
# 971  -1.710160
# 972  -0.562915
# 973   0.201915
# 974  -1.710160
# 975  -1.710160
#
# [950 rows x 14 columns]

# %%
cols_to_nan = ['GambleChoice', 'Outcome',
       'Profit', 'TotalProfit', 'GambleEV', 'CR', 'choiceEV', 'RPE',
       'totalCPE', 'decisionCPE', 'totalRegret', 'decisionRegret',
       'totalRelief', 'decisionRelief', 'totalCF', 'decisionCF', 'pRPE',
       'nRPE']

cols_to_zscore = cols_to_nan.copy()
cols_to_zscore.remove('GambleChoice')
cols_to_zscore.remove('Outcome')

# %%
# Load all subj behav data 
all_behav = pd.concat([pd.read_csv(f'{behav_dir}behavior_preprocessed/{subj_id}_task_data').assign(subj_id = subj_id) for subj_id in subj_ids]).reset_index(drop=True)
# NaN all data for regressor variables for no response trials
all_behav[cols_to_nan].iloc[(all_behav.GambleChoice!='gamble') & (all_behav.GambleChoice != 'safe')] = np.nan
# all_behav = all_behav[(all_behav.GambleChoice=='gamble') | (all_behav.GambleChoice == 'safe')].reset_index(drop=True)

# NaN all data for regressor variables for no outcome trials 
all_behav[cols_to_nan].iloc[(all_behav.Outcome!='good') & (all_behav.Outcome != 'bad')] = np.nan
# all_behav = all_behav[(all_behav.Outcome=='good') | (all_behav.Outcome == 'bad')].reset_index(drop=True)
# all_behav.Round = all_behav.Round.astype('Int64') # Round converts to float when nans are introduced to df 

all_behav[cols_to_zscore] = pd.DataFrame({f'{col}':zscore(all_behav[col]) for col in cols_to_zscore})

all_behav
# Out:
#       Round  Trial Num TrialType   TrialOnset  ChoiceOnset  DecisionOnset  \
# 0         1       25.0       mix   513.380590   513.390239     515.450091
# 1         2      117.0      loss   522.640856   522.641563     524.596127
# 2         3       79.0      gain   531.174799   531.175599     532.759061
# 3         4       42.0       mix   545.592613   545.593355     548.084966
# 4         5       85.0      gain   555.337336   555.345720     557.114656
# ...     ...        ...       ...          ...          ...            ...
# 2847    146       74.0      gain  1887.903226  1887.904228    1889.144100
# 2848    147       88.0      gain  1895.726328  1895.727413    1896.891048
# 2849    148      144.0      loss  1905.271849  1905.272834    1907.119859
# 2850    149       87.0      gain  1914.370711  1914.383463    1915.948606
# 2851    150       77.0      gain  1922.933750  1922.934745    1924.411432
#
#       FeedbackOnset        RT  SafeBet  LowBet  ...  decisionCPE totalRegret  \
# 0        515.457173  2.059852      0.0   -1.10  ...    -0.802918   -0.167804
# 1        526.627092  1.954564     -0.3   -0.95  ...    -0.902402   -0.730295
# 2        534.780269  1.583462      0.4    0.00  ...     1.497661    0.675933
# 3        548.092333  2.491611      0.0   -0.80  ...     0.900754    0.675933
# 4        559.135069  1.768936      0.5    0.00  ...     0.826141    0.675933
# ...             ...       ...      ...     ...  ...          ...         ...
# 2847    1891.160797  1.239872      0.4    0.00  ...     0.515252    0.675933
# 2848    1898.907664  1.163636      0.5    0.00  ...     1.522532    0.675933
# 2849    1907.126331  1.847025     -0.6   -1.33  ...     0.813705    0.675933
# 2850    1917.965770  1.565143      0.5    0.00  ...    -0.715869   -1.662847
# 2851    1926.428648  1.476687      0.4    0.00  ...     0.975367    0.675933
#
#      decisionRegret totalRelief decisionRelief   totalCF  decisionCF  \
# 0         -0.691616   -0.676564      -0.682435  0.631093    0.890652
# 1         -0.882426   -0.676564      -0.682435  0.010697   -0.383415
# 2          0.667899    1.578898       1.773396  0.010697    0.641696
# 3          0.667899    0.397465       0.852460 -0.860034   -1.115638
# 4          0.667899    0.988181       0.737343  0.010697    0.788140
# ...             ...         ...            ...       ...         ...
# 2847       0.667899    0.518294       0.257688  0.010697    0.641696
# 2848       0.667899    1.740002       1.811768  0.010697    0.788140
# 2849       0.667899    0.303488       0.718156 -1.436893   -1.891794
# 2850      -0.524658   -0.676564      -0.682435  1.730390    0.788140
# 2851       0.667899    1.015032       0.967577  0.010697    0.641696
#
#           pRPE      nRPE  subj_id
# 0    -0.453244  0.501065    MS002
# 1    -0.453244 -0.954618    MS002
# 2     1.862125  0.501065    MS002
# 3    -0.453244  0.501065    MS002
# 4     1.255719  0.501065    MS002
# ...        ...       ...      ...
# 2847  0.773350  0.501065    DA023
# 2848  2.027508  0.501065    DA023
# 2849 -0.453244  0.501065    DA023
# 2850 -0.453244 -1.919966    DA023
# 2851  1.283283  0.501065    DA023
#
# [2852 rows x 33 columns]

# %% [markdown]
# # Format Data Frame for GLM inputs

# %%
vif_vars = ['Profit', 'TotalProfit', 'CR', 'choiceEV', 'RPE','decisionCPE']
# vif_vars = ['Profit', 'TotalProfit', 'GambleEV', 'RPE','decisionCPE']
# vif_vars = ['TotalProfit', 'GambleEV', 'RPE','decisionCPE']
# vif_vars = ['TotalProfit','RPE','decisionCPE']
# vif_vars = ['GambleEV','TotalProfit','RPE','decisionCPE']
# vif_vars = ['GambleEV','TotalProfit','decisionRegret','decisionRelief']
# vif_vars = ['GambleEV','TotalProfit','pRPE','nRPE']
# vif_vars = ['GambleEV','TotalProfit','decisionRegret','decisionRelief','nRPE','pRPE']
# vif_vars = ['Profit','TotalProfit','decisionCPE'] 
# vif_vars = ['GambleEV','TotalProfit','RPE','decisionCPE']
# vif_vars = ['choiceEV','CR','Profit', 'TotalProfit', 'decisionCPE']
# vif_vars = ['choiceEV','CR','TotalProfit','RPE','decisionCPE']
# vif_vars = ['choiceEV','CR','decisionCPE']
# vif_vars = ['GambleEV','decisionCPE']
# vif_vars = ['CR', 'choiceEV','RPE']
# vif_vars = ['GambleEV','RPE']
# vif_vars = ['choiceEV','CR','RPE','decisionCPE']
# vif_vars = ['GambleEV','RPE','decisionCPE']
# vif_vars = ['TotalProfit','CR', 'choiceEV','decisionCPE']
# vif_vars = ['TotalProfit','GambleEV','decisionCPE']
# vif_vars = ['TotalProfit','Profit','decisionCPE']
# vif_vars = ['TotalProfit','Profit','decisionCPE']
# vif_vars = ['choiceEV','CR','RPE','decisionCPE']
# vif_vars = ['GambleEV','RPE','decisionCPE']
test_vif = vif_scores(all_behav,vif_vars)
test_vif
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#        feature         VIF
# 0       Profit  399.342984
# 1  TotalProfit    1.025656
# 2           CR   37.531085
# 3     choiceEV  124.649273
# 4          RPE  232.709565
# 5  decisionCPE    2.109811

# %%
# main_var = 'decisionCPE'
main_var = 'decisionRegret'
iter_vars = ['GambleEV','TotalProfit','Profit','RPE','decisionRelief']

var_combos = [[v,main_var] for v in iter_vars]

for i in range(1,len(iter_vars)-1):
    iter_list = [list(tup)+[main_var] for tup in list(itertools.combinations(iter_vars,i+1))]
    var_combos.extend(iter_list)
# var_combos

# %%
# # remove var combos that contain RPE and Profit because they are collinear 
var_combos = [combo for combo in var_combos if ('RPE' in combo and 'Profit' not in combo)|
              ('RPE' not in combo and 'Profit' in combo)|('RPE' not in combo and 'Profit' not in combo)]
# # remove var combos that contain GambleEV and Profit because they are collinear 
var_combos = [combo for combo in var_combos if ('GambleEV' in combo and 'Profit' not in combo)|
              ('GambleEV' not in combo and 'Profit' in combo)|('GambleEV' not in combo and 'Profit' not in combo)]
var_combos
# Out:
# [['GambleEV', 'decisionRegret'],
#  ['TotalProfit', 'decisionRegret'],
#  ['Profit', 'decisionRegret'],
#  ['RPE', 'decisionRegret'],
#  ['decisionRelief', 'decisionRegret'],
#  ['GambleEV', 'TotalProfit', 'decisionRegret'],
#  ['GambleEV', 'RPE', 'decisionRegret'],
#  ['GambleEV', 'decisionRelief', 'decisionRegret'],
#  ['TotalProfit', 'Profit', 'decisionRegret'],
#  ['TotalProfit', 'RPE', 'decisionRegret'],
#  ['TotalProfit', 'decisionRelief', 'decisionRegret'],
#  ['Profit', 'decisionRelief', 'decisionRegret'],
#  ['RPE', 'decisionRelief', 'decisionRegret'],
#  ['GambleEV', 'TotalProfit', 'RPE', 'decisionRegret'],
#  ['GambleEV', 'TotalProfit', 'decisionRelief', 'decisionRegret'],
#  ['GambleEV', 'RPE', 'decisionRelief', 'decisionRegret'],
#  ['TotalProfit', 'Profit', 'decisionRelief', 'decisionRegret'],
#  ['TotalProfit', 'RPE', 'decisionRelief', 'decisionRegret'],
#  ['GambleEV', 'TotalProfit', 'RPE', 'decisionRelief', 'decisionRegret']]

# %%
[vif_scores(all_behav,test_vars).VIF.tolist() for test_vars in var_combos]
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# [[1.0028518241227422, 1.0028518241227404],
#  [1.0090479708136895, 1.009047970813688],
#  [1.2313648399135289, 1.2313648399135222],
#  [1.3835130286584596, 1.3835130286584623],
#  [1.262229807074776, 1.2622298070747735],
#  [1.0033972352688825, 1.0095967517971152, 1.0121432560104449],
#  [1.0045837832668747, 1.3859024026251554, 1.3897832191596804],
#  [1.0136121630113208, 1.275773204167632, 1.273621553945943],
#  [1.0146806481048727, 1.2382385277574748, 1.2348989342016],
#  [1.0095975840666607, 1.3842666073962444, 1.3900244802561],
#  [1.010315113500155, 1.2638148905543884, 1.2681640164370234],
#  [1.594207864317411, 1.6341677298141546, 1.334766895883742],
#  [1.8875261142726816, 1.7220594773706053, 1.4338448695111785],
#  [1.0050867932086782,
#   1.0101031044925979,
#   1.386597487485519,
#   1.396587101761667],
#  [1.0140090210679156,
#   1.010710680667878,
#   1.2771808162683433,
#   1.2798879886797756],
#  [1.0138041827429545,
#   1.8878836891629043,
#   1.737865104106177,
#   1.4440540319272541],
#  [1.0146806705436877,
#   1.6010964135214472,
#   1.6341677659524072,
#   1.3383066780400465],
#  [1.0103500577004558,
#   1.8875913989444937,
#   1.7233429633584842,
#   1.4394098531238895],
#  [1.01420446146834,
#   1.0107489726390337,
#   1.8879552138723523,
#   1.738976309198561,
#   1.4499248471547486]]
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# # Test Mood Models

# %%
model_inputs = {f'{("_").join(vars)}':{} for vars in var_combos}

for model_vars in var_combos:
    # var_key = ("_").join(model_vars)
    model_df = []
    for subj_id in subj_ids: 
        subj_dict = {}
        subj_mood_data = all_mood[all_mood.subj_id == subj_id]
        subj_norm_mood = subj_mood_data.norm_mood.tolist()
        subj_dict['mood'] = subj_norm_mood
        subj_behav_data = all_behav[all_behav.subj_id == subj_id]
        for reg in model_vars:
            # make reg name strings for model data keys
            reg_t1 = reg + '_t1'
            reg_t2 = reg + '_t2'
            reg_t3 = reg + '_t3'
            subj_dict[reg_t1] = [subj_behav_data[reg].iloc[np.where(subj_behav_data.Round==round_num)[0][0]] for round_num in subj_mood_data.t1_round_idx]
            subj_dict[reg_t2] = [subj_behav_data[reg].iloc[np.where(subj_behav_data.Round==round_num)[0][0]] for round_num in subj_mood_data.t2_round_idx]
            subj_dict[reg_t3] = [subj_behav_data[reg].iloc[np.where(subj_behav_data.Round==round_num)[0][0]] for round_num in subj_mood_data.t3_round_idx]

        subj_dict = pd.DataFrame(subj_dict).assign(subj_id = subj_id)
        model_df.append(subj_dict)
    
    model_inputs[("_").join(model_vars)] = pd.concat(model_df)

# [[all_behav[all_behav.subj_id==subj_id].decisionCPE.iloc[np.where(all_behav[all_behav.subj_id==subj_id].Round==round_num)[0 ][0]] for round_num in all_mood[all_mood.subj_id == subj_id].t2_round_idx] for subj_id in subj_ids]

# %%
model_results = {f'{model}':{f'{subj_id}':{} for subj_id in subj_ids} for model in model_inputs.keys()}
gamma_bounds = [(0.0001,1)]
n_inits = 2

for model in model_inputs.keys():
    model_data   = model_inputs[model]
    reg_list     = model.split('_')
    param_bounds = gamma_bounds + [(-10,10) for reg_num in range(len(reg_list)+1)]
    gam_inits    = np.array([np.random.uniform(0,1) for n in range(n_inits)])
    var_inits    = [np.random.uniform(-1,1,n_inits) for n in range(len(reg_list)+1)]

    for subj_id in subj_ids:
        subj_data      = model_inputs[model][model_inputs[model].subj_id == subj_id]
        var_init_grid  = itertools.product(*np.vstack((gam_inits,var_inits)))
        subj_model_fit = parallel_glm_fit(min_negll_glm,fit_swb_glm,var_init_grid,param_bounds,subj_data,reg_list)
        model_results[model][subj_id] = subj_model_fit
# Out:
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    3.0s remaining:    3.9s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    3.3s remaining:    1.5s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    3.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.4s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.4s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.3s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.4s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.4s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.4s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.3s remaining:    0.4s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.2s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   7 out of  16 | elapsed:    0.2s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  11 out of  16 | elapsed:    0.3s remaining:    0.1s
# [Parallel(n_jobs=-2)]: Done  16 out of  16 | elapsed:    0.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.3s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    0.9s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.3s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.0s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.4s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.7s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  19 out of  32 | elapsed:    0.9s remaining:    0.6s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    0.9s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    0.9s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.0s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    0.9s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.0s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.0s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.3s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    0.9s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.4s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.0s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    0.9s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.0s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.2s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.3s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.1s remaining:    0.3s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-2)]: Done  26 out of  32 | elapsed:    1.0s remaining:    0.2s
# [Parallel(n_jobs=-2)]: Done  32 out of  32 | elapsed:    1.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.2s
# ...
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.7s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.7s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.7s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.7s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.9s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.9s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.2s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.2s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    6.0s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    6.0s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.3s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.5s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.0s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.0s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.0s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.0s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.5s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.7s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.7s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.5s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.5s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.8s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.8s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.9s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.9s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.8s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.8s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.7s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.7s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    3.7s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    3.7s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    5.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.6s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.1s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=-2)]: Done  64 out of  64 | elapsed:    4.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   20.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   16.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   17.4s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   17.8s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   18.8s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   20.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   19.6s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   19.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   23.3s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   24.9s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   25.7s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   23.9s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   25.2s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   20.8s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   22.1s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   24.8s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   22.0s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   23.0s finished
# [Parallel(n_jobs=-2)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=-2)]: Done   4 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-2)]: Done  58 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-2)]: Done 128 out of 128 | elapsed:   17.6s finished

# %%
bic_summary = []

for model in model_results.keys():
    model_df = {}
    res = model_results[model]
    mean_bic = np.mean([res[subj_id]['subj_dict']['bic'] for subj_id in subj_ids])
    model_df['model_id'] = model
    model_df['mean_bic'] = mean_bic
    for subj_id in subj_ids:
        model_df[subj_id] = res[subj_id]['subj_dict']['bic']
    bic_summary.append(pd.DataFrame(model_df,index=[0]))

    # pd.DataFrame({f'{subj_id}':res[subj_id]['subj_dict']['bic'] for subj_id in subj_ids})
bic_summary = pd.concat(bic_summary).reset_index(drop=True)
bic_summary
# Out:
#                                              model_id    mean_bic       MS002  \
# 0                             GambleEV_decisionRegret  332.010715  332.762531
# 1                          TotalProfit_decisionRegret  330.001420  339.507967
# 2                               Profit_decisionRegret  329.497028  331.701339
# 3                                  RPE_decisionRegret  331.557161  336.822295
# 4                       decisionRelief_decisionRegret  332.840133  339.381383
# 5                 GambleEV_TotalProfit_decisionRegret  376.076183  382.654810
# 6                         GambleEV_RPE_decisionRegret  377.536297  379.956451
# 7              GambleEV_decisionRelief_decisionRegret  378.857738  381.420308
# 8                   TotalProfit_Profit_decisionRegret  373.205710  381.176347
# 9                      TotalProfit_RPE_decisionRegret  375.909150  385.520001
# 10          TotalProfit_decisionRelief_decisionRegret  377.006298  388.242480
# 11               Profit_decisionRelief_decisionRegret  377.520358  381.696021
# 12                  RPE_decisionRelief_decisionRegret  380.051090  386.498147
# 13            GambleEV_TotalProfit_RPE_decisionRegret  421.902507  429.685137
# 14  GambleEV_TotalProfit_decisionRelief_decisionRe...  423.079505  431.331509
# 15         GambleEV_RPE_decisionRelief_decisionRegret  425.892289  429.726198
# 16   TotalProfit_Profit_decisionRelief_decisionRegret  421.220548  431.139018
# 17      TotalProfit_RPE_decisionRelief_decisionRegret  424.394907  435.076153
# 18  GambleEV_TotalProfit_RPE_decisionRelief_decisi...  470.486757  479.454306
#
#          MS003       MS009       MS011       MS015       MS017       MS019  \
# 0   332.346366  339.841127  339.416228  338.260106  317.098794  337.613609
# 1   333.583637  329.149688  339.272609  340.359568  322.489145  337.562148
# 2   333.240522  340.331621  337.047039  340.398968  314.663259  335.048117
# 3   333.657329  340.631380  335.980372  339.697034  319.775738  335.017771
# 4   333.648736  338.945766  339.581936  339.913545  320.219088  334.437918
# 5   381.937229  378.761745  389.016333  386.655160  366.978247  387.543841
# 6   382.341352  390.605401  385.477278  388.023200  364.855605  384.762857
# 7   382.305140  388.643630  389.277419  387.566040  366.001985  384.436530
# 8   382.976967  378.522282  386.685452  388.892991  364.658442  385.033134
# 9   383.583400  379.110813  385.742491  388.499831  369.712277  384.954599
# 10  383.576261  379.147997  389.138607  388.381848  370.004975  384.436630
# 11  382.936053  388.210848  387.020721  386.158675  364.663168  384.301892
# 12  383.648734  387.401139  385.310845  388.816332  369.168401  384.319049
# 13  431.102219  428.640172  435.106962  436.441480  414.735317  434.729596
# 14  431.920808  428.738603  438.820878  435.862026  415.992884  434.435495
# 15  431.281108  437.244242  435.014411  436.110406  414.695455  434.300273
# 16  432.630645  428.229705  436.669438  434.552175  414.657239  434.301850
# 17  433.573982  428.445762  435.106643  437.376229  418.972388  434.317811
# 18  481.949864  477.808714  484.710621  484.704077  464.636989  484.299191
#
#          MS022  ...       MS025       MS026       MS027       MS029  \
# 0   336.259218  ...  326.784448  338.700839  341.691303  320.857928
# 1   324.032622  ...  335.527956  320.390211  341.774747  307.769202
# 2   332.435647  ...  312.159184  335.071215  341.659074  329.464079
# 3   333.731077  ...  334.362291  332.759619  341.676499  334.344100
# 4   333.566526  ...  336.244165  337.601338  341.434157  334.531049
# 5   369.870403  ...  374.813556  370.373841  391.689200  342.353681
# 6   383.707736  ...  366.016261  382.498247  391.588611  369.231642
# 7   383.409131  ...  370.192522  387.573267  391.376321  370.642602
# 8   363.982083  ...  358.753679  370.141018  391.653561  345.895749
# 9   366.931545  ...  380.575481  369.901749  391.666124  354.929054
# 10  370.853981  ...  380.125517  370.285819  391.418204  357.155096
# 11  382.433118  ...  359.318899  384.753782  391.431008  377.535272
# 12  383.048864  ...  382.777726  382.581379  391.433909  384.335382
# 13  413.853503  ...  414.543096  419.900523  441.588317  392.114420
# 14  418.298139  ...  417.227396  420.256738  441.372297  392.184323
# 15  432.799394  ...  414.787251  432.086281  441.376162  419.060109
# 16  413.542676  ...  405.313031  420.123671  441.416785  394.728665
# 17  416.780112  ...  426.924356  419.899433  441.418158  404.840918
# 18  462.697890  ...  463.037763  469.898863  491.372254  442.090693
#
#          MS033       MS035       MS041       MS043         DA8       DA023
# 0   335.367810  325.322980  328.989347  302.620061  335.475799  338.610891
# 1   331.022232  325.139137  339.029944  314.103448  335.716313  337.285533
# 2   334.036202  319.556177  338.528183  275.269817  330.825020  339.929997
# 3   334.173637  317.621592  335.689991  290.492098  325.900376  341.242773
# 4   334.748901  303.640853  338.865814  301.210293  335.433360  340.646676
# 5   380.929870  375.111124  378.044402  352.599466  385.379044  384.449581
# 6   384.150284  366.009467  376.495137  327.883239  375.741548  388.584652
# 7   384.694345  353.046708  377.146834  338.069923  384.822211  388.607163
# 8   380.794797  369.158350  387.775901  324.900964  380.816825  384.687035
# 9   380.597872  367.573066  385.390305  340.488891  375.886955  386.615640
# 10  380.771996  353.555095  388.505793  350.917476  385.326514  385.929124
# 11  383.952580  350.799649  385.223028  322.772503  380.741516  389.870770
# 12  384.149028  352.027558  385.566566  337.637631  375.705417  390.635837
# 13  430.470718  415.752054  425.691028  377.703749  425.726924  433.911308
# 14  430.644539  403.016180  426.358029  388.005449  434.756208  433.946203
# 15  434.126239  400.009566  426.253245  373.980118  425.573839  438.530015
# 16  430.696741  400.788076  434.683995  372.549048  430.732890  434.536766
# 17  430.579165  402.007925  435.256197  387.631240  425.687565  435.924965
# 18  480.450326  449.970048  475.480965  423.908981  475.555043  483.581885
#
# [19 rows x 21 columns]

# %%
bic_summary
# Out:
#                                              model_id    mean_bic       MS002  \
# 0                             GambleEV_decisionRegret  332.010715  332.762531
# 1                          TotalProfit_decisionRegret  330.001420  339.507967
# 2                               Profit_decisionRegret  329.497028  331.701339
# 3                                  RPE_decisionRegret  331.557161  336.822295
# 4                       decisionRelief_decisionRegret  332.840133  339.381383
# 5                 GambleEV_TotalProfit_decisionRegret  376.076183  382.654810
# 6                         GambleEV_RPE_decisionRegret  377.536297  379.956451
# 7              GambleEV_decisionRelief_decisionRegret  378.857738  381.420308
# 8                   TotalProfit_Profit_decisionRegret  373.205710  381.176347
# 9                      TotalProfit_RPE_decisionRegret  375.909150  385.520001
# 10          TotalProfit_decisionRelief_decisionRegret  377.006298  388.242480
# 11               Profit_decisionRelief_decisionRegret  377.520358  381.696021
# 12                  RPE_decisionRelief_decisionRegret  380.051090  386.498147
# 13            GambleEV_TotalProfit_RPE_decisionRegret  421.902507  429.685137
# 14  GambleEV_TotalProfit_decisionRelief_decisionRe...  423.079505  431.331509
# 15         GambleEV_RPE_decisionRelief_decisionRegret  425.892289  429.726198
# 16   TotalProfit_Profit_decisionRelief_decisionRegret  421.220548  431.139018
# 17      TotalProfit_RPE_decisionRelief_decisionRegret  424.394907  435.076153
# 18  GambleEV_TotalProfit_RPE_decisionRelief_decisi...  470.486757  479.454306
#
#          MS003       MS009       MS011       MS015       MS017       MS019  \
# 0   332.346366  339.841127  339.416228  338.260106  317.098794  337.613609
# 1   333.583637  329.149688  339.272609  340.359568  322.489145  337.562148
# 2   333.240522  340.331621  337.047039  340.398968  314.663259  335.048117
# 3   333.657329  340.631380  335.980372  339.697034  319.775738  335.017771
# 4   333.648736  338.945766  339.581936  339.913545  320.219088  334.437918
# 5   381.937229  378.761745  389.016333  386.655160  366.978247  387.543841
# 6   382.341352  390.605401  385.477278  388.023200  364.855605  384.762857
# 7   382.305140  388.643630  389.277419  387.566040  366.001985  384.436530
# 8   382.976967  378.522282  386.685452  388.892991  364.658442  385.033134
# 9   383.583400  379.110813  385.742491  388.499831  369.712277  384.954599
# 10  383.576261  379.147997  389.138607  388.381848  370.004975  384.436630
# 11  382.936053  388.210848  387.020721  386.158675  364.663168  384.301892
# 12  383.648734  387.401139  385.310845  388.816332  369.168401  384.319049
# 13  431.102219  428.640172  435.106962  436.441480  414.735317  434.729596
# 14  431.920808  428.738603  438.820878  435.862026  415.992884  434.435495
# 15  431.281108  437.244242  435.014411  436.110406  414.695455  434.300273
# 16  432.630645  428.229705  436.669438  434.552175  414.657239  434.301850
# 17  433.573982  428.445762  435.106643  437.376229  418.972388  434.317811
# 18  481.949864  477.808714  484.710621  484.704077  464.636989  484.299191
#
#          MS022  ...       MS025       MS026       MS027       MS029  \
# 0   336.259218  ...  326.784448  338.700839  341.691303  320.857928
# 1   324.032622  ...  335.527956  320.390211  341.774747  307.769202
# 2   332.435647  ...  312.159184  335.071215  341.659074  329.464079
# 3   333.731077  ...  334.362291  332.759619  341.676499  334.344100
# 4   333.566526  ...  336.244165  337.601338  341.434157  334.531049
# 5   369.870403  ...  374.813556  370.373841  391.689200  342.353681
# 6   383.707736  ...  366.016261  382.498247  391.588611  369.231642
# 7   383.409131  ...  370.192522  387.573267  391.376321  370.642602
# 8   363.982083  ...  358.753679  370.141018  391.653561  345.895749
# 9   366.931545  ...  380.575481  369.901749  391.666124  354.929054
# 10  370.853981  ...  380.125517  370.285819  391.418204  357.155096
# 11  382.433118  ...  359.318899  384.753782  391.431008  377.535272
# 12  383.048864  ...  382.777726  382.581379  391.433909  384.335382
# 13  413.853503  ...  414.543096  419.900523  441.588317  392.114420
# 14  418.298139  ...  417.227396  420.256738  441.372297  392.184323
# 15  432.799394  ...  414.787251  432.086281  441.376162  419.060109
# 16  413.542676  ...  405.313031  420.123671  441.416785  394.728665
# 17  416.780112  ...  426.924356  419.899433  441.418158  404.840918
# 18  462.697890  ...  463.037763  469.898863  491.372254  442.090693
#
#          MS033       MS035       MS041       MS043         DA8       DA023
# 0   335.367810  325.322980  328.989347  302.620061  335.475799  338.610891
# 1   331.022232  325.139137  339.029944  314.103448  335.716313  337.285533
# 2   334.036202  319.556177  338.528183  275.269817  330.825020  339.929997
# 3   334.173637  317.621592  335.689991  290.492098  325.900376  341.242773
# 4   334.748901  303.640853  338.865814  301.210293  335.433360  340.646676
# 5   380.929870  375.111124  378.044402  352.599466  385.379044  384.449581
# 6   384.150284  366.009467  376.495137  327.883239  375.741548  388.584652
# 7   384.694345  353.046708  377.146834  338.069923  384.822211  388.607163
# 8   380.794797  369.158350  387.775901  324.900964  380.816825  384.687035
# 9   380.597872  367.573066  385.390305  340.488891  375.886955  386.615640
# 10  380.771996  353.555095  388.505793  350.917476  385.326514  385.929124
# 11  383.952580  350.799649  385.223028  322.772503  380.741516  389.870770
# 12  384.149028  352.027558  385.566566  337.637631  375.705417  390.635837
# 13  430.470718  415.752054  425.691028  377.703749  425.726924  433.911308
# 14  430.644539  403.016180  426.358029  388.005449  434.756208  433.946203
# 15  434.126239  400.009566  426.253245  373.980118  425.573839  438.530015
# 16  430.696741  400.788076  434.683995  372.549048  430.732890  434.536766
# 17  430.579165  402.007925  435.256197  387.631240  425.687565  435.924965
# 18  480.450326  449.970048  475.480965  423.908981  475.555043  483.581885
#
# [19 rows x 21 columns]

# %%
[(bic_summary.model_id[np.where(bic_summary.mean_bic == bic)[0][0]],bic) for bic in bic_list]
# Out:
# [('Profit_decisionRegret', 329.4970282879325),
#  ('TotalProfit_decisionRegret', 330.00141984922476),
#  ('RPE_decisionRegret', 331.5571614389317),
#  ('GambleEV_decisionRegret', 332.01071460691736),
#  ('decisionRelief_decisionRegret', 332.8401329042436),
#  ('TotalProfit_Profit_decisionRegret', 373.20570967485145),
#  ('TotalProfit_RPE_decisionRegret', 375.9091495061467),
#  ('GambleEV_TotalProfit_decisionRegret', 376.07618307837754),
#  ('TotalProfit_decisionRelief_decisionRegret', 377.0062981823135),
#  ('Profit_decisionRelief_decisionRegret', 377.5203576494665),
#  ('GambleEV_RPE_decisionRegret', 377.5362969526691),
#  ('GambleEV_decisionRelief_decisionRegret', 378.85773839462036),
#  ('RPE_decisionRelief_decisionRegret', 380.05109031571527),
#  ('TotalProfit_Profit_decisionRelief_decisionRegret', 421.2205477181331),
#  ('GambleEV_TotalProfit_RPE_decisionRegret', 421.9025070036936),
#  ('GambleEV_TotalProfit_decisionRelief_decisionRegret', 423.07950455892404),
#  ('TotalProfit_RPE_decisionRelief_decisionRegret', 424.39490728644324),
#  ('GambleEV_RPE_decisionRelief_decisionRegret', 425.8922894786246),
#  ('GambleEV_TotalProfit_RPE_decisionRelief_decisionRegret', 470.4867568724025)]

# %%
ordered_model_ids = [bic_summary.model_id[np.where(bic_summary.mean_bic == bic)[0][0]] for bic in bic_list]
ordered_model_ids
# Out:
# ['Profit_decisionRegret',
#  'TotalProfit_decisionRegret',
#  'RPE_decisionRegret',
#  'GambleEV_decisionRegret',
#  'decisionRelief_decisionRegret',
#  'TotalProfit_Profit_decisionRegret',
#  'TotalProfit_RPE_decisionRegret',
#  'GambleEV_TotalProfit_decisionRegret',
#  'TotalProfit_decisionRelief_decisionRegret',
#  'Profit_decisionRelief_decisionRegret',
#  'GambleEV_RPE_decisionRegret',
#  'GambleEV_decisionRelief_decisionRegret',
#  'RPE_decisionRelief_decisionRegret',
#  'TotalProfit_Profit_decisionRelief_decisionRegret',
#  'GambleEV_TotalProfit_RPE_decisionRegret',
#  'GambleEV_TotalProfit_decisionRelief_decisionRegret',
#  'TotalProfit_RPE_decisionRelief_decisionRegret',
#  'GambleEV_RPE_decisionRelief_decisionRegret',
#  'GambleEV_TotalProfit_RPE_decisionRelief_decisionRegret']

# %%
best_model_by_subj = [bic_summary.model_id[np.where(bic_summary[subj_id] == np.min(bic_summary[subj_id]))[0][0]] for subj_id in subj_ids]
subj_bdi_bic = list(zip(subj_ids,subj_bdi,best_model_by_subj))
subj_bdi_bic
# Out:
# [('MS002', 14, 'Profit_decisionRegret'),
#  ('MS003', 8, 'GambleEV_decisionRegret'),
#  ('MS009', 16, 'TotalProfit_decisionRegret'),
#  ('MS011', 13, 'RPE_decisionRegret'),
#  ('MS015', 26, 'GambleEV_decisionRegret'),
#  ('MS017', 26, 'Profit_decisionRegret'),
#  ('MS019', 12, 'decisionRelief_decisionRegret'),
#  ('MS022', 10, 'TotalProfit_decisionRegret'),
#  ('MS024', 16, 'TotalProfit_decisionRegret'),
#  ('MS025', 10, 'Profit_decisionRegret'),
#  ('MS026', 9, 'TotalProfit_decisionRegret'),
#  ('MS027', 22, 'decisionRelief_decisionRegret'),
#  ('MS029', 32, 'TotalProfit_decisionRegret'),
#  ('MS033', 39, 'TotalProfit_decisionRegret'),
#  ('MS035', 15, 'decisionRelief_decisionRegret'),
#  ('MS041', 10, 'GambleEV_decisionRegret'),
#  ('MS043', 23, 'Profit_decisionRegret'),
#  ('DA8', 13, 'RPE_decisionRegret'),
#  ('DA023', 14, 'TotalProfit_decisionRegret')]

# %%
highBDI_models = []
lowBDI_models = []
for tup in subj_bdi_bic:
    if tup[1] >= 20:
        highBDI_models.append(tup[2])
    else:
        lowBDI_models.append(tup[2])
    # subj_bdi_bic

# %%
# np.unique(highBDI_models)
highBDI_models
# Out:
# ['GambleEV_decisionRegret',
#  'Profit_decisionRegret',
#  'decisionRelief_decisionRegret',
#  'TotalProfit_decisionRegret',
#  'TotalProfit_decisionRegret',
#  'Profit_decisionRegret']

# %%
lowBDI_models
# Out:
# ['Profit_decisionRegret',
#  'GambleEV_decisionRegret',
#  'TotalProfit_decisionRegret',
#  'RPE_decisionRegret',
#  'decisionRelief_decisionRegret',
#  'TotalProfit_decisionRegret',
#  'TotalProfit_decisionRegret',
#  'Profit_decisionRegret',
#  'TotalProfit_decisionRegret',
#  'decisionRelief_decisionRegret',
#  'GambleEV_decisionRegret',
#  'RPE_decisionRegret',
#  'TotalProfit_decisionRegret']

# %%
np.unique(lowBDI_models)
# Out:
# array(['GambleEV_RPE', 'GambleEV_decisionCPE', 'Profit_decisionCPE',
#        'RPE_decisionCPE', 'TotalProfit_decisionCPE'], dtype='<U23')

# %%
Profit_decisionRegret

# %%
model_param_dfs = {}

for mod in ordered_model_ids:
    best_dict = {}
    param_names = ['subj_id','gamma','beta0']
    param_names.extend(mod.split('_'))
    best_dict = {f'{param}':[] for param in param_names}
    for subj_id in subj_ids:
        subj_params = model_results[mod][subj_id]['subj_dict']['params']
        [best_dict[key].append(val) for key,val in list(zip(param_names[1:],subj_params))]
        best_dict['subj_id'].append(subj_id)
    model_param_dfs[mod] = pd.DataFrame(best_dict).assign(model_id=mod,bdi=subj_bdi)

# %%
model_param_dfs
# Out:
# {'Profit_decisionRegret':    subj_id     gamma     beta0    Profit  decisionRegret  \
#  0    MS002  0.719192  0.011947  0.416648        0.026837
#  1    MS003  0.000100  0.006133  0.094203        0.366488
#  2    MS009  1.000000  0.006365  0.040861        0.070244
#  3    MS011  0.357255  0.006711  0.295155        0.052115
#  4    MS015  0.482174 -0.011092 -0.223335        0.199627
#  5    MS017  0.793657 -0.084237  0.257562        0.376224
#  6    MS019  0.334798  0.024676  0.252761        0.019812
#  7    MS022  0.129592 -0.014849  0.341392        0.071046
#  8    MS024  0.234288 -0.054354  0.334149        0.132099
#  9    MS025  0.913242  0.062926  0.750522        0.078865
#  10   MS026  0.422003 -0.008876  0.299740       -0.236875
#  11   MS027  0.446274 -0.001120 -0.052190        0.076510
#  12   MS029  0.956333  0.044674  0.181851        0.076933
#  13   MS033  0.313220 -0.014198  0.156133        0.267629
#  14   MS035  0.227186  0.056188  0.400540        0.355639
#  15   MS041  0.820301  0.006555  0.122930        0.035627
#  16   MS043  0.517714 -0.101669  0.542600        0.378977
#  17     DA8  0.495133  0.026442  0.357108        0.199574
#  18   DA023  0.000100  0.006698  0.222008       -0.149940
#
#                   model_id  bdi
#  0   Profit_decisionRegret   14
#  1   Profit_decisionRegret    8
#  2   Profit_decisionRegret   16
#  3   Profit_decisionRegret   13
#  4   Profit_decisionRegret   26
#  5   Profit_decisionRegret   26
#  6   Profit_decisionRegret   12
#  7   Profit_decisionRegret   10
#  8   Profit_decisionRegret   16
#  9   Profit_decisionRegret   10
#  10  Profit_decisionRegret    9
#  11  Profit_decisionRegret   22
#  12  Profit_decisionRegret   32
#  13  Profit_decisionRegret   39
#  14  Profit_decisionRegret   15
#  15  Profit_decisionRegret   10
#  16  Profit_decisionRegret   23
#  17  Profit_decisionRegret   13
#  18  Profit_decisionRegret   14  ,
#  'TotalProfit_decisionRegret':    subj_id     gamma     beta0  TotalProfit  decisionRegret  \
#  0    MS002  0.000100  0.001383     0.653068        0.089456
#  1    MS003  0.000100 -0.021080    -0.081697        0.450065
#  2    MS009  1.000000 -0.008650    -0.300519        0.103317
#  3    MS011  0.000100  0.019179     0.100011        0.209376
#  4    MS015  0.000100 -0.202462    -0.260630       -0.001096
#  5    MS017  0.571681 -0.042032    -0.012663        0.590847
#  6    MS019  0.249499  0.056253     0.078043        0.240997
#  7    MS022  0.000100 -0.170553     0.712986        0.285718
#  8    MS024  0.431592 -0.469261     0.332297        0.188519
#  9    MS025  0.000100  0.311838     1.028579        0.190866
#  10   MS026  0.000100  0.307179     1.794708       -0.178733
#  11   MS027  0.389250  0.005290    -0.033542        0.055522
#  12   MS029  0.000100  0.520748     0.825087        0.150715
#  13   MS033  0.000100  0.064328     0.535460        0.388477
#  14   MS035  0.000100  0.049966     0.136605        0.523448
#  15   MS041  0.000100 -0.094714     0.457922        0.140515
#  16   MS043  0.327585 -0.071172    -0.036168        0.925103
#  17     DA8  0.299742 -0.008987     0.120820        0.298905
#  18   DA023  1.000000  0.015955    -0.273969        0.071494
#
#                        model_id  bdi
#  0   TotalProfit_decisionRegret   14
#  1   TotalProfit_decisionRegret    8
#  2   TotalProfit_decisionRegret   16
#  3   TotalProfit_decisionRegret   13
#  4   TotalProfit_decisionRegret   26
#  5   TotalProfit_decisionRegret   26
#  6   TotalProfit_decisionRegret   12
#  7   TotalProfit_decisionRegret   10
#  8   TotalProfit_decisionRegret   16
#  9   TotalProfit_decisionRegret   10
#  10  TotalProfit_decisionRegret    9
#  11  TotalProfit_decisionRegret   22
#  12  TotalProfit_decisionRegret   32
#  13  TotalProfit_decisionRegret   39
#  14  TotalProfit_decisionRegret   15
#  15  TotalProfit_decisionRegret   10
#  16  TotalProfit_decisionRegret   23
#  17  TotalProfit_decisionRegret   13
#  18  TotalProfit_decisionRegret   14  ,
#  'RPE_decisionRegret':    subj_id     gamma     beta0       RPE  decisionRegret            model_id  \
#  0    MS002  0.205712  0.000523  0.341596        0.008905  RPE_decisionRegret
#  1    MS003  0.000100  0.009287 -0.011693        0.453496  RPE_decisionRegret
#  2    MS009  0.000100  0.005994  0.111941        0.074814  RPE_decisionRegret
#  3    MS011  0.694475  0.000312  0.324403       -0.039438  RPE_decisionRegret
#  4    MS015  1.000000 -0.002449  0.146087       -0.089745  RPE_decisionRegret
#  5    MS017  0.640271 -0.050741  0.194101        0.421746  RPE_decisionRegret
#  6    MS019  0.367554  0.002561  0.230910        0.022784  RPE_decisionRegret
#  7    MS022  0.544523 -0.007829  0.252283        0.033555  RPE_decisionRegret
#  8    MS024  0.047331 -0.045998  0.598614        0.045038  RPE_decisionRegret
#  9    MS025  0.377940 -0.008377  0.796551        0.156761  RPE_decisionRegret
#  10   MS026  0.000100 -0.011569  0.359738       -0.283920  RPE_decisionRegret
#  11   MS027  0.421482 -0.001585 -0.047412        0.089790  RPE_decisionRegret
#  12   MS029  1.000000  0.041763 -0.048398        0.224884  RPE_decisionRegret
#  13   MS033  0.356078 -0.013852  0.162723        0.256813  RPE_decisionRegret
#  14   MS035  0.311350  0.045444  0.373584        0.290230  RPE_decisionRegret
#  15   MS041  1.000000  0.012804 -0.192205        0.313954  RPE_decisionRegret
#  16   MS043  0.506228 -0.029233  0.546558        0.265539  RPE_decisionRegret
#  17     DA8  0.480158  0.030364  0.674301        0.183139  RPE_decisionRegret
#  18   DA023  1.000000 -0.002992  0.060699        0.030720  RPE_decisionRegret
#
#      bdi
#  0    14
#  1     8
#  2    16
#  3    13
#  4    26
#  5    26
#  6    12
#  7    10
#  8    16
#  9    10
#  10    9
#  11   22
#  12   32
#  13   39
#  14   15
#  15   10
#  16   23
#  17   13
#  18   14  ,
#  'GambleEV_decisionRegret':    subj_id     gamma     beta0  GambleEV  decisionRegret  \
#  0    MS002  0.981769  0.003406  0.262742        0.155669
#  1    MS003  0.000100  0.007886  0.150555        0.431307
#  2    MS009  1.000000  0.006318  0.066483        0.092424
#  3    MS011  0.000100  0.008825  0.072751        0.250571
#  4    MS015  0.575065  0.011826 -0.233244        0.080592
#  5    MS017  0.770711 -0.077070  0.198641        0.504251
#  6    MS019  0.301277  0.032297  0.027019        0.237832
#  7    MS022  0.229152 -0.028190  0.185928        0.383216
#  8    MS024  0.427019 -0.016883 -0.135080        0.078959
#  9    MS025  0.789918  0.017734  0.361138        0.166660
#  10   MS026  0.000100 -0.025255 -0.004106       -0.194122
#  11   MS027  0.264571 -0.000758 -0.049438        0.048927
#  12   MS029  1.000000  0.031770  0.245874        0.155714
#  13   MS033  0.143618 -0.008413  0.043059        0.429095
#  14   MS035  0.219943  0.047730  0.015261        0.519805
#  15   MS041  0.827404  0.005585  0.316021        0.061713
#  16   MS043  0.482883 -0.121204  0.325946        0.840325
#  17     DA8  0.437759  0.017378  0.094384        0.284900
#  18   DA023  0.000100  0.005307  0.270921       -0.049627
#
#                     model_id  bdi
#  0   GambleEV_decisionRegret   14
#  1   GambleEV_decisionRegret    8
#  2   GambleEV_decisionRegret   16
#  3   GambleEV_decisionRegret   13
#  4   GambleEV_decisionRegret   26
#  5   GambleEV_decisionRegret   26
#  6   GambleEV_decisionRegret   12
#  7   GambleEV_decisionRegret   10
#  8   GambleEV_decisionRegret   16
#  9   GambleEV_decisionRegret   10
#  10  GambleEV_decisionRegret    9
#  11  GambleEV_decisionRegret   22
#  12  GambleEV_decisionRegret   32
#  13  GambleEV_decisionRegret   39
#  14  GambleEV_decisionRegret   15
#  15  GambleEV_decisionRegret   10
#  16  GambleEV_decisionRegret   23
#  17  GambleEV_decisionRegret   13
#  18  GambleEV_decisionRegret   14  ,
#  'decisionRelief_decisionRegret':    subj_id     gamma     beta0  decisionRelief  decisionRegret  \
#  0    MS002  0.482559 -0.005193        0.152125        0.066102
#  1    MS003  0.000100  0.009044       -0.017585        0.453734
#  2    MS009  0.000100  0.000243       -0.294412        0.207487
#  3    MS011  0.000100  0.010120        0.056733        0.202777
#  4    MS015  0.000100  0.069057        0.402650       -0.077910
#  5    MS017  0.517158 -0.049006        0.199729        0.497540
#  6    MS019  0.260207  0.030662        0.251017        0.139861
#  7    MS022  0.639468 -0.013115        0.218934        0.151406
#  8    MS024  0.006337  0.028454        0.233564        0.092264
#  9    MS025  0.289681 -0.004115        0.334707        0.041810
#  10   MS026  0.000100 -0.016601        0.179634       -0.245059
#  11   MS027  0.484913 -0.000064       -0.079118        0.099281
#  12   MS029  1.000000  0.038538       -0.020773        0.204589
#  13   MS033  0.228424 -0.019977        0.108471        0.349459
#  14   MS035  0.234155  0.081458        0.674165        0.264098
#  15   MS041  0.964537  0.010457       -0.085335        0.187242
#  16   MS043  0.290191 -0.124595        0.367200        0.606822
#  17     DA8  0.425142  0.015404        0.145162        0.246119
#  18   DA023  0.795787 -0.005674        0.109429        0.022599
#
#                           model_id  bdi
#  0   decisionRelief_decisionRegret   14
#  1   decisionRelief_decisionRegret    8
#  2   decisionRelief_decisionRegret   16
#  3   decisionRelief_decisionRegret   13
#  4   decisionRelief_decisionRegret   26
#  5   decisionRelief_decisionRegret   26
#  6   decisionRelief_decisionRegret   12
#  7   decisionRelief_decisionRegret   10
#  8   decisionRelief_decisionRegret   16
#  9   decisionRelief_decisionRegret   10
#  10  decisionRelief_decisionRegret    9
#  11  decisionRelief_decisionRegret   22
#  12  decisionRelief_decisionRegret   32
#  13  decisionRelief_decisionRegret   39
#  14  decisionRelief_decisionRegret   15
#  15  decisionRelief_decisionRegret   10
#  16  decisionRelief_decisionRegret   23
#  17  decisionRelief_decisionRegret   13
#  18  decisionRelief_decisionRegret   14  ,
#  'TotalProfit_Profit_decisionRegret':    subj_id     gamma     beta0  TotalProfit    Profit  decisionRegret  \
#  0    MS002  0.663538  0.008642     0.174389  0.433549        0.019220
#  1    MS003  0.000100 -0.034291    -0.156459  0.118774        0.361244
#  2    MS009  1.000000 -0.005422    -0.304943  0.058885        0.081730
#  3    MS011  0.350676  0.011161     0.064258  0.296133        0.028389
#  4    MS015  0.519544 -0.137806    -0.142254 -0.222678        0.199148
#  5    MS017  0.796383 -0.059678     0.003698  0.257723        0.374364
#  6    MS019  0.328013  0.023181     0.028065  0.251815        0.020547
#  7    MS022  0.000100 -0.117426     0.748640  0.387263       -0.009545
#  8    MS024  0.378438 -0.333547     0.349071  0.268312        0.185917
#  9    MS025  0.854212  0.180780     0.257607  0.775113        0.086601
#  10   MS026  0.000100  0.196780     1.722518  0.074271       -0.191897
#  11   MS027  0.448657  0.002117    -0.018291 -0.050675        0.075902
#  12   MS029  0.539746  0.359312     0.451100  0.284160       -0.015292
#  13   MS033  0.068005  0.037734     0.458826  0.074460        0.322699
#  14   MS035  0.171827  0.037449     0.112605  0.426092        0.342702
#  15   MS041  0.647042 -0.046431     0.167630  0.149624        0.019255
#  16   MS043  0.529928 -0.082370     0.021811  0.546139        0.359061
#  17     DA8  0.494494  0.014023     0.021186  0.355882        0.199211
#  18   DA023  0.828144  0.010582    -0.360089  0.208874        0.042573
#
#                               model_id  bdi
#  0   TotalProfit_Profit_decisionRegret   14
#  1   TotalProfit_Profit_decisionRegret    8
#  2   TotalProfit_Profit_decisionRegret   16
#  3   TotalProfit_Profit_decisionRegret   13
#  4   TotalProfit_Profit_decisionRegret   26
#  5   TotalProfit_Profit_decisionRegret   26
#  6   TotalProfit_Profit_decisionRegret   12
#  7   TotalProfit_Profit_decisionRegret   10
#  8   TotalProfit_Profit_decisionRegret   16
#  9   TotalProfit_Profit_decisionRegret   10
#  10  TotalProfit_Profit_decisionRegret    9
#  11  TotalProfit_Profit_decisionRegret   22
#  12  TotalProfit_Profit_decisionRegret   32
#  13  TotalProfit_Profit_decisionRegret   39
#  14  TotalProfit_Profit_decisionRegret   15
#  15  TotalProfit_Profit_decisionRegret   10
#  16  TotalProfit_Profit_decisionRegret   23
#  17  TotalProfit_Profit_decisionRegret   13
#  18  TotalProfit_Profit_decisionRegret   14  ,
#  'TotalProfit_RPE_decisionRegret':    subj_id     gamma     beta0  TotalProfit       RPE  decisionRegret  \
#  0    MS002  0.061912 -0.000368     0.572889  0.347113       -0.019300
#  1    MS003  0.000100 -0.013734    -0.080765 -0.002540        0.452376
#  2    MS009  1.000000 -0.005890    -0.302230  0.016014        0.096324
#  3    MS011  0.660330  0.006527     0.036846  0.325078       -0.051648
#  4    MS015  1.000000 -0.116135    -0.075725  0.139264       -0.075614
#  5    MS017  0.633484 -0.020586    -0.016736  0.196138        0.426161
#  6    MS019  0.354052  0.015130     0.055553  0.232409        0.020517
#  7    MS022  0.131737 -0.105573     0.668881  0.393004       -0.161021
#  8    MS024  0.285066 -0.305762     0.369601  0.300823        0.155985
#  9    MS025  0.270024  0.180438     0.661813  0.892376        0.135777
#  10   MS026  0.000100  0.189646     1.651499  0.100198       -0.205103
#  11   MS027  0.422424  0.002853    -0.025645 -0.046356        0.089342
#  12   MS029  0.000100  0.368302     0.883387  0.184765        0.024431
#  13   MS033  0.135237  0.037575     0.434948  0.113396        0.285547
#  14   MS035  0.296868  0.030047     0.032004  0.374722        0.289316
#  15   MS041  1.000000 -0.021144     0.066041 -0.190547        0.307238
#  16   MS043  0.507751 -0.021021     0.002420  0.546775        0.263480
#  17     DA8  0.480571  0.024692    -0.026336  0.677262        0.183570
#  18   DA023  1.000000  0.010505    -0.285837  0.086524        0.042843
#
#                            model_id  bdi
#  0   TotalProfit_RPE_decisionRegret   14
#  1   TotalProfit_RPE_decisionRegret    8
#  2   TotalProfit_RPE_decisionRegret   16
#  3   TotalProfit_RPE_decisionRegret   13
#  4   TotalProfit_RPE_decisionRegret   26
#  5   TotalProfit_RPE_decisionRegret   26
#  6   TotalProfit_RPE_decisionRegret   12
#  7   TotalProfit_RPE_decisionRegret   10
#  8   TotalProfit_RPE_decisionRegret   16
#  9   TotalProfit_RPE_decisionRegret   10
#  10  TotalProfit_RPE_decisionRegret    9
#  11  TotalProfit_RPE_decisionRegret   22
#  12  TotalProfit_RPE_decisionRegret   32
#  13  TotalProfit_RPE_decisionRegret   39
#  14  TotalProfit_RPE_decisionRegret   15
#  15  TotalProfit_RPE_decisionRegret   10
#  16  TotalProfit_RPE_decisionRegret   23
#  17  TotalProfit_RPE_decisionRegret   13
#  18  TotalProfit_RPE_decisionRegret   14  ,
#  'GambleEV_TotalProfit_decisionRegret':    subj_id     gamma     beta0  GambleEV  TotalProfit  decisionRegret  \
#  0    MS002  0.955693  0.002443  0.266257     0.058284        0.158852
#  1    MS003  1.000000 -0.051392  0.200444    -0.077028        0.110698
#  2    MS009  1.000000 -0.005408  0.043469    -0.295604        0.107613
#  3    MS011  0.000100  0.012409  0.072706     0.099971        0.224065
#  4    MS015  0.595408 -0.123019 -0.232711    -0.131657        0.083568
#  5    MS017  0.779447 -0.068977  0.203395     0.019415        0.496091
#  6    MS019  0.254470  0.036988  0.021206     0.071961        0.237666
#  7    MS022  0.000100 -0.128047  0.254522     0.747944        0.342175
#  8    MS024  0.452870 -0.311749 -0.021801     0.323040        0.178320
#  9    MS025  0.747785  0.135896  0.356913     0.256800        0.170830
#  10   MS026  0.000100  0.204959 -0.014366     1.795656       -0.181021
#  11   MS027  0.270337  0.001286 -0.047146    -0.014273        0.049613
#  12   MS029  0.787950  0.309369  0.251678     0.295718        0.133510
#  13   MS033  0.000100  0.043989 -0.042142     0.558866        0.396874
#  14   MS035  0.000100  0.033260  0.022004     0.142585        0.524921
#  15   MS041  0.795803 -0.045446  0.330847     0.136662        0.053911
#  16   MS043  0.477513 -0.076201  0.325027    -0.007281        0.846924
#  17     DA8  0.415493 -0.000977  0.089654     0.084369        0.284810
#  18   DA023  0.000100  0.016061  0.317393    -0.772679        0.015600
#
#                                 model_id  bdi
#  0   GambleEV_TotalProfit_decisionRegret   14
#  1   GambleEV_TotalProfit_decisionRegret    8
#  2   GambleEV_TotalProfit_decisionRegret   16
#  3   GambleEV_TotalProfit_decisionRegret   13
#  4   GambleEV_TotalProfit_decisionRegret   26
#  5   GambleEV_TotalProfit_decisionRegret   26
#  6   GambleEV_TotalProfit_decisionRegret   12
#  7   GambleEV_TotalProfit_decisionRegret   10
#  8   GambleEV_TotalProfit_decisionRegret   16
#  9   GambleEV_TotalProfit_decisionRegret   10
#  10  GambleEV_TotalProfit_decisionRegret    9
#  11  GambleEV_TotalProfit_decisionRegret   22
#  12  GambleEV_TotalProfit_decisionRegret   32
#  13  GambleEV_TotalProfit_decisionRegret   39
#  14  GambleEV_TotalProfit_decisionRegret   15
#  15  GambleEV_TotalProfit_decisionRegret   10
#  16  GambleEV_TotalProfit_decisionRegret   23
#  17  GambleEV_TotalProfit_decisionRegret   13
#  18  GambleEV_TotalProfit_decisionRegret   14  ,
#  'TotalProfit_decisionRelief_decisionRegret':    subj_id     gamma     beta0  TotalProfit  decisionRelief  decisionRegret  \
#  0    MS002  0.000100 -0.003315     0.719377        0.185525        0.018980
#  1    MS003  0.000100 -0.013154    -0.078803       -0.012920        0.458082
#  2    MS009  1.000000 -0.005647    -0.299487       -0.003310        0.104584
#  3    MS011  0.000100  0.013776     0.105970        0.069749        0.167095
#  4    MS015  0.000100 -0.088546    -0.256384        0.397574       -0.092123
#  5    MS017  0.520503 -0.009555    -0.035366        0.209708        0.499744
#  6    MS019  0.261834  0.018504    -0.008857        0.251795        0.139726
#  7    MS022  0.000100 -0.108777     0.707323        0.214486        0.159118
#  8    MS024  0.732751 -0.352205     0.245041       -0.159593        0.174925
#  9    MS025  0.042015  0.252629     1.136815        0.420261       -0.062655
#  10   MS026  0.000100  0.203215     1.769664        0.047245       -0.192508
#  11   MS027  0.487759  0.004797    -0.029420       -0.079199        0.099449
#  12   MS029  0.000100  0.343696     0.828824        0.068164        0.113732
#  13   MS033  0.003007  0.038087     0.517067        0.061932        0.336226
#  14   MS035  0.243851  0.054939    -0.039153        0.674168        0.266659
#  15   MS041  0.876831 -0.028004     0.088559       -0.085849        0.190016
#  16   MS043  0.283760 -0.066092    -0.033043        0.367064        0.624483
#  17     DA8  0.412935 -0.002877     0.088209        0.142939        0.245236
#  18   DA023  0.693495  0.009978    -0.396029        0.156453        0.038080
#
#                                       model_id  bdi
#  0   TotalProfit_decisionRelief_decisionRegret   14
#  1   TotalProfit_decisionRelief_decisionRegret    8
#  2   TotalProfit_decisionRelief_decisionRegret   16
#  3   TotalProfit_decisionRelief_decisionRegret   13
#  4   TotalProfit_decisionRelief_decisionRegret   26
#  5   TotalProfit_decisionRelief_decisionRegret   26
#  6   TotalProfit_decisionRelief_decisionRegret   12
#  7   TotalProfit_decisionRelief_decisionRegret   10
#  8   TotalProfit_decisionRelief_decisionRegret   16
#  9   TotalProfit_decisionRelief_decisionRegret   10
#  10  TotalProfit_decisionRelief_decisionRegret    9
#  11  TotalProfit_decisionRelief_decisionRegret   22
#  12  TotalProfit_decisionRelief_decisionRegret   32
#  13  TotalProfit_decisionRelief_decisionRegret   39
#  14  TotalProfit_decisionRelief_decisionRegret   15
#  15  TotalProfit_decisionRelief_decisionRegret   10
#  16  TotalProfit_decisionRelief_decisionRegret   23
#  17  TotalProfit_decisionRelief_decisionRegret   13
#  18  TotalProfit_decisionRelief_decisionRegret   14  ,
#  'Profit_decisionRelief_decisionRegret':    subj_id     gamma     beta0    Profit  decisionRelief  decisionRegret  \
#  0    MS002  0.713869  0.007769  0.415161        0.009778        0.022726
#  1    MS003  0.000100  0.004683  0.144567       -0.097048        0.388113
#  2    MS009  0.776746  0.006541  0.155469       -0.189877        0.111865
#  3    MS011  0.359371  0.004832  0.302283       -0.027806        0.064239
#  4    MS015  0.059816  0.062936 -0.516604        0.772577        0.243864
#  5    MS017  0.794200 -0.056158  0.257906       -0.001018        0.376450
#  6    MS019  0.273325  0.019360  0.090075        0.189589        0.087144
#  7    MS022  0.119135 -0.009947  0.350917       -0.011044        0.069493
#  8    MS024  0.197391 -0.028715  0.314458        0.037281        0.125987
#  9    MS025  0.820338  0.039729  0.793834        0.160376        0.032236
#  10   MS026  0.678973 -0.003834  0.315565       -0.105343       -0.212400
#  11   MS027  0.493509  0.000016 -0.009289       -0.074306        0.099647
#  12   MS029  1.000000  0.026284  0.225678       -0.132148        0.112161
#  13   MS033  0.318373 -0.011518  0.133742        0.041347        0.257311
#  14   MS035  0.181768  0.059768  0.253996        0.643413        0.173614
#  15   MS041  1.000000  0.008877  0.223655       -0.202720        0.046013
#  16   MS043  0.479240 -0.074094  0.495666        0.115621        0.343578
#  17     DA8  0.498042  0.017841  0.346109        0.051845        0.184443
#  18   DA023  0.816229 -0.003488  0.138518        0.043102        0.015759
#
#                                  model_id  bdi
#  0   Profit_decisionRelief_decisionRegret   14
#  1   Profit_decisionRelief_decisionRegret    8
#  2   Profit_decisionRelief_decisionRegret   16
#  3   Profit_decisionRelief_decisionRegret   13
#  4   Profit_decisionRelief_decisionRegret   26
#  5   Profit_decisionRelief_decisionRegret   26
#  6   Profit_decisionRelief_decisionRegret   12
#  7   Profit_decisionRelief_decisionRegret   10
#  8   Profit_decisionRelief_decisionRegret   16
#  9   Profit_decisionRelief_decisionRegret   10
#  10  Profit_decisionRelief_decisionRegret    9
#  11  Profit_decisionRelief_decisionRegret   22
#  12  Profit_decisionRelief_decisionRegret   32
#  13  Profit_decisionRelief_decisionRegret   39
#  14  Profit_decisionRelief_decisionRegret   15
#  15  Profit_decisionRelief_decisionRegret   10
#  16  Profit_decisionRelief_decisionRegret   23
#  17  Profit_decisionRelief_decisionRegret   13
#  18  Profit_decisionRelief_decisionRegret   14  ,
#  'GambleEV_RPE_decisionRegret':    subj_id     gamma     beta0  GambleEV       RPE  decisionRegret  \
#  0    MS002  0.869161  0.003230  0.301465  0.188083        0.116994
#  1    MS003  0.000100  0.005675  0.150535 -0.011294        0.441971
#  2    MS009  0.000100  0.004534 -0.025336  0.107414        0.071829
#  3    MS011  0.567683  0.002306  0.083929  0.340028       -0.024661
#  4    MS015  0.714390  0.005828 -0.175877  0.085716       -0.005223
#  5    MS017  0.813465 -0.047714  0.179024  0.138875        0.394607
#  6    MS019  0.358956  0.002202  0.076208  0.245761       -0.006806
#  7    MS022  0.652807 -0.004966 -0.047977  0.243301        0.016889
#  8    MS024  0.232418 -0.035747 -0.176929  0.619838       -0.005771
#  9    MS025  0.991373  0.020062  0.340715  0.464255        0.132291
#  10   MS026  0.189871 -0.004516  0.074811  0.372777       -0.271336
#  11   MS027  0.302567 -0.000437 -0.046013 -0.047751        0.086304
#  12   MS029  1.000000  0.024252  0.259580 -0.110911        0.225710
#  13   MS033  0.358709 -0.008854  0.018140  0.160076        0.253534
#  14   MS035  0.267708  0.032305  0.153467  0.442610        0.272505
#  15   MS041  0.852666  0.006456  0.285407 -0.160678        0.217353
#  16   MS043  0.548228 -0.032561  0.254296  0.480131        0.304918
#  17     DA8  0.497365  0.021380  0.048244  0.653625        0.179273
#  18   DA023  0.000100  0.003721  0.271518  0.028366       -0.068667
#
#                         model_id  bdi
#  0   GambleEV_RPE_decisionRegret   14
#  1   GambleEV_RPE_decisionRegret    8
#  2   GambleEV_RPE_decisionRegret   16
#  3   GambleEV_RPE_decisionRegret   13
#  4   GambleEV_RPE_decisionRegret   26
#  5   GambleEV_RPE_decisionRegret   26
#  6   GambleEV_RPE_decisionRegret   12
#  7   GambleEV_RPE_decisionRegret   10
#  8   GambleEV_RPE_decisionRegret   16
#  9   GambleEV_RPE_decisionRegret   10
#  10  GambleEV_RPE_decisionRegret    9
#  11  GambleEV_RPE_decisionRegret   22
#  12  GambleEV_RPE_decisionRegret   32
#  13  GambleEV_RPE_decisionRegret   39
#  14  GambleEV_RPE_decisionRegret   15
#  15  GambleEV_RPE_decisionRegret   10
#  16  GambleEV_RPE_decisionRegret   23
#  17  GambleEV_RPE_decisionRegret   13
#  18  GambleEV_RPE_decisionRegret   14  ,
#  'GambleEV_decisionRelief_decisionRegret':    subj_id     gamma     beta0  GambleEV  decisionRelief  decisionRegret  \
#  0    MS002  1.000000 -0.001405  0.270984        0.114078        0.101384
#  1    MS003  0.000100  0.005711  0.152470       -0.030040        0.450431
#  2    MS009  1.000000  0.006727  0.078309       -0.094264        0.131489
#  3    MS011  0.000100  0.006460  0.080256        0.071405        0.210417
#  4    MS015  0.238366  0.036861 -0.278567        0.291136        0.012937
#  5    MS017  0.760274 -0.054865  0.188907        0.103794        0.450208
#  6    MS019  0.261297  0.020247 -0.005655        0.251516        0.140559
#  7    MS022  0.799608 -0.007224 -0.067219        0.207448        0.107847
#  8    MS024  0.102344  0.026874 -0.181826        0.315630        0.014547
#  9    MS025  0.614108  0.011481  0.447600        0.337724        0.071150
#  10   MS026  0.000100 -0.010861 -0.022526        0.183325       -0.249719
#  11   MS027  0.380244  0.000258 -0.036315       -0.077748        0.099140
#  12   MS029  1.000000  0.019940  0.247324       -0.036768        0.175256
#  13   MS033  0.227043 -0.012489  0.029756        0.105444        0.343420
#  14   MS035  0.226631  0.055037  0.076919        0.690038        0.265757
#  15   MS041  0.890679  0.006662  0.308869       -0.127235        0.133384
#  16   MS043  0.388544 -0.096887  0.310789        0.327475        0.617150
#  17     DA8  0.538897  0.010124  0.110684        0.146376        0.218062
#  18   DA023  0.000100  0.003679  0.267572        0.011486       -0.056404
#
#                                    model_id  bdi
#  0   GambleEV_decisionRelief_decisionRegret   14
#  1   GambleEV_decisionRelief_decisionRegret    8
#  2   GambleEV_decisionRelief_decisionRegret   16
#  3   GambleEV_decisionRelief_decisionRegret   13
#  4   GambleEV_decisionRelief_decisionRegret   26
#  5   GambleEV_decisionRelief_decisionRegret   26
#  6   GambleEV_decisionRelief_decisionRegret   12
#  7   GambleEV_decisionRelief_decisionRegret   10
#  8   GambleEV_decisionRelief_decisionRegret   16
#  9   GambleEV_decisionRelief_decisionRegret   10
#  10  GambleEV_decisionRelief_decisionRegret    9
#  11  GambleEV_decisionRelief_decisionRegret   22
#  12  GambleEV_decisionRelief_decisionRegret   32
#  13  GambleEV_decisionRelief_decisionRegret   39
#  14  GambleEV_decisionRelief_decisionRegret   15
#  15  GambleEV_decisionRelief_decisionRegret   10
#  16  GambleEV_decisionRelief_decisionRegret   23
#  17  GambleEV_decisionRelief_decisionRegret   13
#  18  GambleEV_decisionRelief_decisionRegret   14  ,
#  'RPE_decisionRelief_decisionRegret':    subj_id     gamma     beta0       RPE  decisionRelief  decisionRegret  \
#  0    MS002  0.229737 -0.001900  0.312576        0.093581       -0.016492
#  1    MS003  0.000100  0.006022  0.000246       -0.017726        0.453593
#  2    MS009  0.000100 -0.000911  0.225724       -0.385850        0.168318
#  3    MS011  0.758689  0.001747  0.373642       -0.103621       -0.014630
#  4    MS015  1.000000 -0.018524  0.219832       -0.112962       -0.099765
#  5    MS017  0.583753 -0.032825  0.146740        0.112531        0.412206
#  6    MS019  0.296368  0.013743  0.081956        0.186438        0.087914
#  7    MS022  0.612571 -0.006224  0.129808        0.138537        0.065157
#  8    MS024  0.006101 -0.020104  0.569322        0.076651        0.025987
#  9    MS025  0.237385 -0.003951  0.786536        0.246823        0.038847
#  10   MS026  0.601230 -0.000777  0.350235       -0.097240       -0.263141
#  11   MS027  0.485449 -0.000041 -0.002530       -0.077769        0.100301
#  12   MS029  1.000000  0.028416 -0.055649        0.010765        0.223811
#  13   MS033  0.351133 -0.010483  0.144377        0.025148        0.256797
#  14   MS035  0.204741  0.054879  0.163931        0.614761        0.192967
#  15   MS041  1.000000  0.007828 -0.216759        0.039018        0.313059
#  16   MS043  0.441892 -0.036182  0.462762        0.153026        0.255356
#  17     DA8  0.475817  0.019876  0.712837       -0.081492        0.204998
#  18   DA023  0.761723 -0.003630 -0.018776        0.122657        0.027241
#
#                               model_id  bdi
#  0   RPE_decisionRelief_decisionRegret   14
#  1   RPE_decisionRelief_decisionRegret    8
#  2   RPE_decisionRelief_decisionRegret   16
#  3   RPE_decisionRelief_decisionRegret   13
#  4   RPE_decisionRelief_decisionRegret   26
#  5   RPE_decisionRelief_decisionRegret   26
#  6   RPE_decisionRelief_decisionRegret   12
#  7   RPE_decisionRelief_decisionRegret   10
#  8   RPE_decisionRelief_decisionRegret   16
#  9   RPE_decisionRelief_decisionRegret   10
#  10  RPE_decisionRelief_decisionRegret    9
#  11  RPE_decisionRelief_decisionRegret   22
#  12  RPE_decisionRelief_decisionRegret   32
#  13  RPE_decisionRelief_decisionRegret   39
#  14  RPE_decisionRelief_decisionRegret   15
#  15  RPE_decisionRelief_decisionRegret   10
#  16  RPE_decisionRelief_decisionRegret   23
#  17  RPE_decisionRelief_decisionRegret   13
#  18  RPE_decisionRelief_decisionRegret   14  ,
#  'TotalProfit_Profit_decisionRelief_decisionRegret':    subj_id     gamma     beta0  TotalProfit    Profit  decisionRelief  \
#  0    MS002  0.644599  0.006115     0.186466  0.429967        0.027623
#  1    MS003  0.000100 -0.027411    -0.168241  0.174302       -0.103433
#  2    MS009  1.000000 -0.002582    -0.290964  0.083642       -0.050799
#  3    MS011  0.354474  0.008484     0.063145  0.301545       -0.021788
#  4    MS015  0.088143 -0.053434    -0.231198 -0.515923        0.754306
#  5    MS017  0.798986 -0.045226     0.004341  0.259068       -0.003914
#  6    MS019  0.273565  0.014258    -0.001578  0.089947        0.189813
#  7    MS022  0.000100 -0.090455     0.758737  0.466755       -0.105241
#  8    MS024  0.588726 -0.313405     0.290944  0.355525       -0.293150
#  9    MS025  0.698979  0.140667     0.327305  0.844208        0.199918
#  10   MS026  0.000100  0.147765     1.719840  0.065551        0.021041
#  11   MS027  0.495008  0.003469    -0.027870 -0.006344       -0.075907
#  12   MS029  0.490201  0.272114     0.477748  0.331807       -0.092616
#  13   MS033  0.074465  0.026664     0.455580  0.050241        0.045147
#  14   MS035  0.177779  0.044709     0.015631  0.258157        0.642745
#  15   MS041  1.000000 -0.023100     0.088342  0.230233       -0.203678
#  16   MS043  0.489169 -0.063813     0.017465  0.500637        0.111666
#  17     DA8  0.497435  0.010611     0.021645  0.344831        0.052016
#  18   DA023  0.778897  0.007693    -0.380830  0.184960        0.052561
#
#      decisionRegret                                          model_id  bdi
#  0         0.007047  TotalProfit_Profit_decisionRelief_decisionRegret   14
#  1         0.383897  TotalProfit_Profit_decisionRelief_decisionRegret    8
#  2         0.092089  TotalProfit_Profit_decisionRelief_decisionRegret   16
#  3         0.037926  TotalProfit_Profit_decisionRelief_decisionRegret   13
#  4         0.231254  TotalProfit_Profit_decisionRelief_decisionRegret   26
#  5         0.374900  TotalProfit_Profit_decisionRelief_decisionRegret   26
#  6         0.087192  TotalProfit_Profit_decisionRelief_decisionRegret   12
#  7        -0.008035  TotalProfit_Profit_decisionRelief_decisionRegret   10
#  8         0.220433  TotalProfit_Profit_decisionRelief_decisionRegret   16
#  9         0.029962  TotalProfit_Profit_decisionRelief_decisionRegret   10
#  10       -0.196486  TotalProfit_Profit_decisionRelief_decisionRegret    9
#  11        0.099543  TotalProfit_Profit_decisionRelief_decisionRegret   22
#  12        0.003343  TotalProfit_Profit_decisionRelief_decisionRegret   32
#  13        0.308856  TotalProfit_Profit_decisionRelief_decisionRegret   39
#  14        0.170993  TotalProfit_Profit_decisionRelief_decisionRegret   15
#  15        0.033538  TotalProfit_Profit_decisionRelief_decisionRegret   10
#  16        0.329248  TotalProfit_Profit_decisionRelief_decisionRegret   23
#  17        0.184017  TotalProfit_Profit_decisionRelief_decisionRegret   13
#  18        0.030439  TotalProfit_Profit_decisionRelief_decisionRegret   14  ,
#  'GambleEV_TotalProfit_RPE_decisionRegret':    subj_id     gamma     beta0  GambleEV  TotalProfit       RPE  \
#  0    MS002  0.826799  0.002747  0.305947     0.104401  0.202394
#  1    MS003  1.000000 -0.042348  0.210790    -0.080313  0.081168
#  2    MS009  0.000100 -0.002641 -0.102010    -0.952630  0.241553
#  3    MS011  0.528422  0.007529  0.095085     0.053044  0.340609
#  4    MS015  0.677953 -0.092367 -0.192166    -0.119185  0.075614
#  5    MS017  0.830653 -0.049290  0.183175     0.018240  0.136499
#  6    MS019  0.350139  0.009049  0.072440     0.040800  0.246038
#  7    MS022  0.000100 -0.089401  0.211414     0.804533  0.342661
#  8    MS024  0.327470 -0.227942 -0.056382     0.348189  0.315267
#  9    MS025  0.941255  0.087486  0.343607     0.164453  0.471495
#  10   MS026  0.000100  0.142063  0.004024     1.649525  0.101394
#  11   MS027  0.305411  0.000184 -0.045103    -0.005199 -0.047473
#  12   MS029  0.754084  0.238747  0.249812     0.317007  0.041905
#  13   MS033  0.099921  0.029412 -0.049431     0.479246  0.114661
#  14   MS035  0.230812  0.023961  0.170134     0.081212  0.454037
#  15   MS041  0.828230 -0.028499  0.298614     0.118780 -0.158471
#  16   MS043  0.558505 -0.032002  0.255531     0.015124  0.480455
#  17     DA8  0.497677  0.019518  0.048390    -0.026910  0.656622
#  18   DA023  0.867291  0.007001  0.163035    -0.325917  0.155627
#
#      decisionRegret                                 model_id  bdi
#  0         0.114450  GambleEV_TotalProfit_RPE_decisionRegret   14
#  1         0.051995  GambleEV_TotalProfit_RPE_decisionRegret    8
#  2         0.022421  GambleEV_TotalProfit_RPE_decisionRegret   16
#  3        -0.040830  GambleEV_TotalProfit_RPE_decisionRegret   13
#  4         0.012943  GambleEV_TotalProfit_RPE_decisionRegret   26
#  5         0.385631  GambleEV_TotalProfit_RPE_decisionRegret   26
#  6        -0.006702  GambleEV_TotalProfit_RPE_decisionRegret   12
#  7        -0.068238  GambleEV_TotalProfit_RPE_decisionRegret   10
#  8         0.132322  GambleEV_TotalProfit_RPE_decisionRegret   16
#  9         0.137716  GambleEV_TotalProfit_RPE_decisionRegret   10
#  10       -0.204776  GambleEV_TotalProfit_RPE_decisionRegret    9
#  11        0.086312  GambleEV_TotalProfit_RPE_decisionRegret   22
#  12        0.106793  GambleEV_TotalProfit_RPE_decisionRegret   32
#  13        0.294221  GambleEV_TotalProfit_RPE_decisionRegret   39
#  14        0.265666  GambleEV_TotalProfit_RPE_decisionRegret   15
#  15        0.207183  GambleEV_TotalProfit_RPE_decisionRegret   10
#  16        0.291857  GambleEV_TotalProfit_RPE_decisionRegret   23
#  17        0.179721  GambleEV_TotalProfit_RPE_decisionRegret   13
#  18        0.065602  GambleEV_TotalProfit_RPE_decisionRegret   14  ,
#  'GambleEV_TotalProfit_decisionRelief_decisionRegret':    subj_id     gamma     beta0  GambleEV  TotalProfit  decisionRelief  \
#  0    MS002  0.982363 -0.001017  0.272504     0.051467        0.115216
#  1    MS003  1.000000 -0.039408  0.201696    -0.078397       -0.011091
#  2    MS009  1.000000 -0.003709  0.045340    -0.291532       -0.012385
#  3    MS011  0.000100  0.010175  0.081618     0.107214        0.084824
#  4    MS015  0.190078 -0.071899 -0.277059    -0.214742        0.331991
#  5    MS017  0.763124 -0.044829  0.190640     0.005548        0.101087
#  6    MS019  0.262661  0.013889 -0.005141    -0.007975        0.252172
#  7    MS022  0.000100 -0.091294  0.204875     0.737074        0.153440
#  8    MS024  0.731899 -0.265006  0.006422     0.245707       -0.162148
#  9    MS025  0.510272  0.119760  0.446048     0.399878        0.392682
#  10   MS026  0.000100  0.152505 -0.019283     1.769246        0.050436
#  11   MS027  0.391783  0.002082 -0.033176    -0.017234       -0.077860
#  12   MS029  0.785978  0.234067  0.249884     0.299167        0.027690
#  13   MS033  0.000100  0.029332 -0.049636     0.545277        0.066059
#  14   MS035  0.232611  0.041545  0.073969    -0.023880        0.689439
#  15   MS041  0.865966 -0.028239  0.320918     0.113706       -0.124364
#  16   MS043  0.383230 -0.067385  0.309113    -0.012274        0.328585
#  17     DA8  0.528494 -0.000050  0.108305     0.060394        0.146360
#  18   DA023  0.687014  0.006517  0.150975    -0.398624        0.146824
#
#      decisionRegret                                           model_id  bdi
#  0         0.102458  GambleEV_TotalProfit_decisionRelief_decisionRe...   14
#  1         0.116696  GambleEV_TotalProfit_decisionRelief_decisionRe...    8
#  2         0.112536  GambleEV_TotalProfit_decisionRelief_decisionRe...   16
#  3         0.174446  GambleEV_TotalProfit_decisionRelief_decisionRe...   13
#  4        -0.006420  GambleEV_TotalProfit_decisionRelief_decisionRe...   26
#  5         0.449191  GambleEV_TotalProfit_decisionRelief_decisionRe...   26
#  6         0.140377  GambleEV_TotalProfit_decisionRelief_decisionRe...   12
#  7         0.240595  GambleEV_TotalProfit_decisionRelief_decisionRe...   10
#  8         0.177795  GambleEV_TotalProfit_decisionRelief_decisionRe...   16
#  9         0.049183  GambleEV_TotalProfit_decisionRelief_decisionRe...   10
#  10       -0.196510  GambleEV_TotalProfit_decisionRelief_decisionRe...    9
#  11        0.099337  GambleEV_TotalProfit_decisionRelief_decisionRe...   22
#  12        0.118438  GambleEV_TotalProfit_decisionRelief_decisionRe...   32
#  13        0.342230  GambleEV_TotalProfit_decisionRelief_decisionRe...   39
#  14        0.267314  GambleEV_TotalProfit_decisionRelief_decisionRe...   15
#  15        0.123536  GambleEV_TotalProfit_decisionRelief_decisionRe...   10
#  16        0.624377  GambleEV_TotalProfit_decisionRelief_decisionRe...   23
#  17        0.218280  GambleEV_TotalProfit_decisionRelief_decisionRe...   13
#  18        0.077884  GambleEV_TotalProfit_decisionRelief_decisionRe...   14  ,
#  'TotalProfit_RPE_decisionRelief_decisionRegret':    subj_id     gamma     beta0  TotalProfit       RPE  decisionRelief  \
#  0    MS002  0.109592 -0.002310     0.566361  0.317063        0.111224
#  1    MS003  0.000100 -0.010516    -0.081216  0.010001       -0.018545
#  2    MS009  0.000100 -0.005130    -0.848770  0.294883       -0.173702
#  3    MS011  0.735410  0.005560     0.031004  0.372858       -0.104136
#  4    MS015  1.000000 -0.109075    -0.082593  0.221218       -0.126485
#  5    MS017  0.573319 -0.007214    -0.031741  0.144516        0.126738
#  6    MS019  0.295663  0.011650     0.008511  0.083747        0.184305
#  7    MS022  0.114100 -0.079762     0.696342  0.458520       -0.071261
#  8    MS024  0.521667 -0.269473     0.299517  0.304111       -0.215046
#  9    MS025  0.108296  0.176047     0.984406  0.812027        0.362136
#  10   MS026  0.000100  0.142385     1.651742  0.097192        0.007645
#  11   MS027  0.488143  0.003585    -0.029296 -0.001093       -0.078615
#  12   MS029  0.000100  0.279543     0.889399  0.209325       -0.031698
#  13   MS033  0.127884  0.027396     0.437365  0.096160        0.021761
#  14   MS035  0.209960  0.041366    -0.019420  0.161662        0.615456
#  15   MS041  1.000000 -0.016781     0.067142 -0.216045        0.040560
#  16   MS043  0.439995 -0.025605    -0.003599  0.461811        0.153731
#  17     DA8  0.476248  0.018752    -0.030488  0.716730       -0.082422
#  18   DA023  0.676048  0.007595    -0.403584 -0.012031        0.166054
#
#      decisionRegret                                       model_id  bdi
#  0        -0.047868  TotalProfit_RPE_decisionRelief_decisionRegret   14
#  1         0.452472  TotalProfit_RPE_decisionRelief_decisionRegret    8
#  2         0.080933  TotalProfit_RPE_decisionRelief_decisionRegret   16
#  3        -0.024548  TotalProfit_RPE_decisionRelief_decisionRegret   13
#  4        -0.085551  TotalProfit_RPE_decisionRelief_decisionRegret   26
#  5         0.416732  TotalProfit_RPE_decisionRelief_decisionRegret   26
#  6         0.086910  TotalProfit_RPE_decisionRelief_decisionRegret   12
#  7        -0.195649  TotalProfit_RPE_decisionRelief_decisionRegret   10
#  8         0.180043  TotalProfit_RPE_decisionRelief_decisionRegret   16
#  9        -0.079035  TotalProfit_RPE_decisionRelief_decisionRegret   10
#  10       -0.206541  TotalProfit_RPE_decisionRelief_decisionRegret    9
#  11        0.099873  TotalProfit_RPE_decisionRelief_decisionRegret   22
#  12        0.024842  TotalProfit_RPE_decisionRelief_decisionRegret   32
#  13        0.284514  TotalProfit_RPE_decisionRelief_decisionRegret   39
#  14        0.195380  TotalProfit_RPE_decisionRelief_decisionRegret   15
#  15        0.306195  TotalProfit_RPE_decisionRelief_decisionRegret   10
#  16        0.258282  TotalProfit_RPE_decisionRelief_decisionRegret   23
#  17        0.205750  TotalProfit_RPE_decisionRelief_decisionRegret   13
#  18        0.040755  TotalProfit_RPE_decisionRelief_decisionRegret   14  ,
#  'GambleEV_RPE_decisionRelief_decisionRegret':    subj_id     gamma     beta0  GambleEV       RPE  decisionRelief  \
#  0    MS002  0.878942  0.001197  0.302152  0.163100        0.056171
#  1    MS003  1.000000  0.000096  0.212765  0.119926       -0.070029
#  2    MS009  0.000100  0.000183 -0.060712  0.217955       -0.396287
#  3    MS011  0.657982  0.002262  0.060915  0.383664       -0.099663
#  4    MS015  0.054439  0.061564 -0.361802 -0.418577        0.792796
#  5    MS017  0.802938 -0.037387  0.178366  0.120725        0.042093
#  6    MS019  0.299342  0.009793  0.023348  0.098959        0.170881
#  7    MS022  0.793107 -0.003932 -0.082171  0.117250        0.135103
#  8    MS024  0.175755 -0.012322 -0.195153  0.575931        0.136550
#  9    MS025  0.892277  0.012868  0.375518  0.427930        0.118170
#  10   MS026  0.537982  0.000200  0.096580  0.390468       -0.133396
#  11   MS027  0.380364  0.000191 -0.036315 -0.002159       -0.076603
#  12   MS029  1.000000  0.019814  0.261436 -0.139058        0.041127
#  13   MS033  0.353306 -0.007568  0.017969  0.141939        0.024859
#  14   MS035  0.180349  0.042493  0.153623  0.242531        0.618339
#  15   MS041  0.871520  0.005397  0.290807 -0.119637       -0.058559
#  16   MS043  0.488857 -0.037897  0.264323  0.398430        0.151465
#  17     DA8  0.490702  0.015872  0.043943  0.691796       -0.074468
#  18   DA023  0.864820 -0.003669  0.149771  0.081583        0.060870
#
#      decisionRegret                                    model_id  bdi
#  0         0.097910  GambleEV_RPE_decisionRelief_decisionRegret   14
#  1         0.062707  GambleEV_RPE_decisionRelief_decisionRegret    8
#  2         0.163696  GambleEV_RPE_decisionRelief_decisionRegret   16
#  3        -0.005263  GambleEV_RPE_decisionRelief_decisionRegret   13
#  4         0.256731  GambleEV_RPE_decisionRelief_decisionRegret   26
#  5         0.386541  GambleEV_RPE_decisionRelief_decisionRegret   26
#  6         0.073964  GambleEV_RPE_decisionRelief_decisionRegret   12
#  7         0.029069  GambleEV_RPE_decisionRelief_decisionRegret   10
#  8        -0.037543  GambleEV_RPE_decisionRelief_decisionRegret   16
#  9         0.106369  GambleEV_RPE_decisionRelief_decisionRegret   10
#  10       -0.246735  GambleEV_RPE_decisionRelief_decisionRegret    9
#  11        0.100046  GambleEV_RPE_decisionRelief_decisionRegret   22
#  12        0.221616  GambleEV_RPE_decisionRelief_decisionRegret   32
#  13        0.253713  GambleEV_RPE_decisionRelief_decisionRegret   39
#  14        0.160263  GambleEV_RPE_decisionRelief_decisionRegret   15
#  15        0.210786  GambleEV_RPE_decisionRelief_decisionRegret   10
#  16        0.297766  GambleEV_RPE_decisionRelief_decisionRegret   23
#  17        0.199811  GambleEV_RPE_decisionRelief_decisionRegret   13
#  18        0.043193  GambleEV_RPE_decisionRelief_decisionRegret   14  ,
#  'GambleEV_TotalProfit_RPE_decisionRelief_decisionRegret':    subj_id     gamma     beta0  GambleEV  TotalProfit       RPE  \
#  0    MS002  0.830772  0.001266  0.307197     0.105124  0.179251
#  1    MS003  0.000100 -0.023376  0.173166    -0.178945  0.038069
#  2    MS009  0.000100 -0.002925 -0.112322    -0.873551  0.282529
#  3    MS011  0.618813  0.005993  0.072258     0.043281  0.382279
#  4    MS015  0.083512 -0.028625 -0.357227    -0.219187 -0.367009
#  5    MS017  0.816856 -0.037535  0.181802     0.013435  0.122473
#  6    MS019  0.298664  0.008841  0.023253     0.007928  0.100558
#  7    MS022  0.000100 -0.073630  0.253131     0.848985  0.525948
#  8    MS024  0.520479 -0.213001 -0.028263     0.297050  0.313862
#  9    MS025  0.787101  0.073947  0.391684     0.214424  0.430964
#  10   MS026  0.000100  0.113796  0.002832     1.650323  0.098413
#  11   MS027  0.391815  0.001651 -0.033197    -0.017067 -0.001115
#  12   MS029  0.760646  0.190493  0.249454     0.313766  0.032262
#  13   MS033  0.090312  0.022909 -0.050006     0.483420  0.096253
#  14   MS035  0.173097  0.033773  0.159047     0.028956  0.248316
#  15   MS041  0.848556 -0.021794  0.302603     0.113608 -0.119791
#  16   MS043  0.495037 -0.033880  0.265200     0.009900  0.400568
#  17     DA8  0.490991  0.015854  0.044061    -0.030715  0.695715
#  18   DA023  0.791574  0.004947  0.163261    -0.357049  0.105099
#
#      decisionRelief  decisionRegret  \
#  0         0.057745        0.094934
#  1        -0.043092        0.437994
#  2        -0.186817        0.069831
#  3        -0.096946       -0.018502
#  4         0.731510        0.214187
#  5         0.033931        0.381636
#  6         0.168964        0.073091
#  7        -0.200195       -0.155231
#  8        -0.204334        0.166790
#  9         0.152629        0.104144
#  10        0.006680       -0.206129
#  11       -0.077268        0.099800
#  12        0.012891        0.105933
#  13        0.022750        0.293035
#  14        0.617146        0.155632
#  15       -0.055442        0.201089
#  16        0.149175        0.289440
#  17       -0.075406        0.200584
#  18        0.079809        0.058238
#
#                                               model_id  bdi
#  0   GambleEV_TotalProfit_RPE_decisionRelief_decisi...   14
#  1   GambleEV_TotalProfit_RPE_decisionRelief_decisi...    8
#  2   GambleEV_TotalProfit_RPE_decisionRelief_decisi...   16
#  3   GambleEV_TotalProfit_RPE_decisionRelief_decisi...   13
#  4   GambleEV_TotalProfit_RPE_decisionRelief_decisi...   26
#  5   GambleEV_TotalProfit_RPE_decisionRelief_decisi...   26
#  6   GambleEV_TotalProfit_RPE_decisionRelief_decisi...   12
#  7   GambleEV_TotalProfit_RPE_decisionRelief_decisi...   10
#  8   GambleEV_TotalProfit_RPE_decisionRelief_decisi...   16
#  9   GambleEV_TotalProfit_RPE_decisionRelief_decisi...   10
#  10  GambleEV_TotalProfit_RPE_decisionRelief_decisi...    9
#  11  GambleEV_TotalProfit_RPE_decisionRelief_decisi...   22
#  12  GambleEV_TotalProfit_RPE_decisionRelief_decisi...   32
#  13  GambleEV_TotalProfit_RPE_decisionRelief_decisi...   39
#  14  GambleEV_TotalProfit_RPE_decisionRelief_decisi...   15
#  15  GambleEV_TotalProfit_RPE_decisionRelief_decisi...   10
#  16  GambleEV_TotalProfit_RPE_decisionRelief_decisi...   23
#  17  GambleEV_TotalProfit_RPE_decisionRelief_decisi...   13
#  18  GambleEV_TotalProfit_RPE_decisionRelief_decisi...   14  }

# %%
sig_models = []
trend_models = []
sig_summary = []
trend_summary = []
for model_df in model_param_dfs.values():
    
    r,p = spearmanr(model_df.bdi,model_df.decisionRegret)
    
    if p < 0.05:
        sig_models.append(model_df.model_id.unique())
        sig_summary.append((model_df.model_id.unique().tolist(),r,p))
    if p < 0.1:
        trend_models.append(model_df.model_id.unique())
        trend_summary.append((model_df.model_id.unique().tolist(),r,p))

sig_summary
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# [(['Profit_decisionRelief_decisionRegret'],
#   0.48591850525696423,
#   0.03491830333491491),
#  (['GambleEV_TotalProfit_RPE_decisionRegret'],
#   0.4595098908408249,
#   0.04778386146349042),
#  (['GambleEV_RPE_decisionRelief_decisionRegret'],
#   0.6434899046065957,
#   0.002952977517164622)]

# %%
sig_summary
# Out:
# [(['Profit_decisionRelief_decisionRegret'],
#   0.48591850525696423,
#   0.03491830333491491),
#  (['GambleEV_TotalProfit_RPE_decisionRegret'],
#   0.4595098908408249,
#   0.04778386146349042),
#  (['GambleEV_RPE_decisionRelief_decisionRegret'],
#   0.6434899046065957,
#   0.002952977517164622)]

# %%
trend_ids = [tm[0] for tm in trend_models]
trend_ids
# Out:
# ['Profit_decisionRegret',
#  'Profit_decisionRelief_decisionRegret',
#  'TotalProfit_Profit_decisionRelief_decisionRegret',
#  'GambleEV_TotalProfit_RPE_decisionRegret',
#  'GambleEV_RPE_decisionRelief_decisionRegret']

# %%
t,p_t = ttest_ind(model_df.decisionRegret[model_df.bdi<20],model_df.decisionRegret[model_df.bdi>=20])
print(t,p_t)
# Out:
# -1.8921864297851603 0.07562447923351368

# %%
sig_models
# Out:
# [array(['Profit_decisionRelief_decisionRegret'], dtype=object),
#  array(['GambleEV_TotalProfit_RPE_decisionRegret'], dtype=object),
#  array(['GambleEV_RPE_decisionRelief_decisionRegret'], dtype=object)]

# %%
sns.set_theme(style='ticks') 
sns.set_context("poster")

for model_id in sig_models:
    model_df = model_param_dfs[model_id[0]]
    
    # r,p = pearsonr(model_df.bdi,model_df.decisionCPE)
    r,p = spearmanr(model_df.bdi,model_df.decisionRegret)
    # t,p_t = ttest_ind(model_df.decisionCPE[model_df.bdi<20],model_df.decisionCPE[model_df.bdi>=20],equal_var=False)
    # print(t,p_t)
    # fig = plt.scatter(model_df.bdi,model_df.decisionCPE)

    fig,ax = plt.subplots(figsize=(7,6))
    sns.regplot(data=model_df,x='bdi',y='decisionRegret',scatter=True)
    vars4title = model_df.model_id.unique()[0].split('_')
    plt.ylabel(f'CPE beta: {(" ").join(vars4title)}')
    plt.title(f'Spearman r: {np.round(r,4)} pval: {np.round(p,4)}')
    sns.despine()
    plt.show()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
sns.set_theme(style='ticks') 
sns.set_context("poster")

for model_id in sig_models:
    model_df = model_param_dfs[model_id[0]]
    
    # r,p = pearsonr(model_df.bdi,model_df.decisionCPE)
    r,p = pearsonr(model_df.bdi,model_df.decisionRegret)
    # t,p_t = ttest_ind(model_df.decisionCPE[model_df.bdi<20],model_df.decisionCPE[model_df.bdi>=20],equal_var=False)
    # print(t,p_t)
    # fig = plt.scatter(model_df.bdi,model_df.decisionCPE)

    fig,ax = plt.subplots(figsize=(7,6))
    sns.regplot(data=model_df,x='bdi',y='decisionRegret',scatter=True)
    vars4title = model_df.model_id.unique()[0].split('_')
    plt.ylabel(f'CPE beta: {(" ").join(vars4title)}')
    plt.title(f'Pearson r: {np.round(r,4)} pval: {np.round(p,4)}')
    sns.despine()
    plt.show()

# %% [markdown]
# # BEST MODEL

# %%
best_model = sig_models[-1][0]
best_model_df = model_param_dfs[best_model]
best_model_df
# Out:
#    subj_id     gamma     beta0  GambleEV       RPE  decisionRelief  \
# 0    MS002  0.878942  0.001197  0.302152  0.163100        0.056171
# 1    MS003  1.000000  0.000096  0.212765  0.119926       -0.070029
# 2    MS009  0.000100  0.000183 -0.060712  0.217955       -0.396287
# 3    MS011  0.657982  0.002262  0.060915  0.383664       -0.099663
# 4    MS015  0.054439  0.061564 -0.361802 -0.418577        0.792796
# 5    MS017  0.802938 -0.037387  0.178366  0.120725        0.042093
# 6    MS019  0.299342  0.009793  0.023348  0.098959        0.170881
# 7    MS022  0.793107 -0.003932 -0.082171  0.117250        0.135103
# 8    MS024  0.175755 -0.012322 -0.195153  0.575931        0.136550
# 9    MS025  0.892277  0.012868  0.375518  0.427930        0.118170
# 10   MS026  0.537982  0.000200  0.096580  0.390468       -0.133396
# 11   MS027  0.380364  0.000191 -0.036315 -0.002159       -0.076603
# 12   MS029  1.000000  0.019814  0.261436 -0.139058        0.041127
# 13   MS033  0.353306 -0.007568  0.017969  0.141939        0.024859
# 14   MS035  0.180349  0.042493  0.153623  0.242531        0.618339
# 15   MS041  0.871520  0.005397  0.290807 -0.119637       -0.058559
# 16   MS043  0.488857 -0.037897  0.264323  0.398430        0.151465
# 17     DA8  0.490702  0.015872  0.043943  0.691796       -0.074468
# 18   DA023  0.864820 -0.003669  0.149771  0.081583        0.060870
#
#     decisionRegret                                    model_id  bdi
# 0         0.097910  GambleEV_RPE_decisionRelief_decisionRegret   14
# 1         0.062707  GambleEV_RPE_decisionRelief_decisionRegret    8
# 2         0.163696  GambleEV_RPE_decisionRelief_decisionRegret   16
# 3        -0.005263  GambleEV_RPE_decisionRelief_decisionRegret   13
# 4         0.256731  GambleEV_RPE_decisionRelief_decisionRegret   26
# 5         0.386541  GambleEV_RPE_decisionRelief_decisionRegret   26
# 6         0.073964  GambleEV_RPE_decisionRelief_decisionRegret   12
# 7         0.029069  GambleEV_RPE_decisionRelief_decisionRegret   10
# 8        -0.037543  GambleEV_RPE_decisionRelief_decisionRegret   16
# 9         0.106369  GambleEV_RPE_decisionRelief_decisionRegret   10
# 10       -0.246735  GambleEV_RPE_decisionRelief_decisionRegret    9
# 11        0.100046  GambleEV_RPE_decisionRelief_decisionRegret   22
# 12        0.221616  GambleEV_RPE_decisionRelief_decisionRegret   32
# 13        0.253713  GambleEV_RPE_decisionRelief_decisionRegret   39
# 14        0.160263  GambleEV_RPE_decisionRelief_decisionRegret   15
# 15        0.210786  GambleEV_RPE_decisionRelief_decisionRegret   10
# 16        0.297766  GambleEV_RPE_decisionRelief_decisionRegret   23
# 17        0.199811  GambleEV_RPE_decisionRelief_decisionRegret   13
# 18        0.043193  GambleEV_RPE_decisionRelief_decisionRegret   14

# %%
depression_weights_plot = best_model_df.copy()
depression_weights_plot['Depression'] = ['Low BDI' if bdi<20 else 'High BDI' for bdi in depression_weights_plot.bdi]
depression_weights_plot
# Out:
#    subj_id     gamma     beta0  GambleEV       RPE  decisionRelief  \
# 0    MS002  0.878942  0.001197  0.302152  0.163100        0.056171
# 1    MS003  1.000000  0.000096  0.212765  0.119926       -0.070029
# 2    MS009  0.000100  0.000183 -0.060712  0.217955       -0.396287
# 3    MS011  0.657982  0.002262  0.060915  0.383664       -0.099663
# 4    MS015  0.054439  0.061564 -0.361802 -0.418577        0.792796
# 5    MS017  0.802938 -0.037387  0.178366  0.120725        0.042093
# 6    MS019  0.299342  0.009793  0.023348  0.098959        0.170881
# 7    MS022  0.793107 -0.003932 -0.082171  0.117250        0.135103
# 8    MS024  0.175755 -0.012322 -0.195153  0.575931        0.136550
# 9    MS025  0.892277  0.012868  0.375518  0.427930        0.118170
# 10   MS026  0.537982  0.000200  0.096580  0.390468       -0.133396
# 11   MS027  0.380364  0.000191 -0.036315 -0.002159       -0.076603
# 12   MS029  1.000000  0.019814  0.261436 -0.139058        0.041127
# 13   MS033  0.353306 -0.007568  0.017969  0.141939        0.024859
# 14   MS035  0.180349  0.042493  0.153623  0.242531        0.618339
# 15   MS041  0.871520  0.005397  0.290807 -0.119637       -0.058559
# 16   MS043  0.488857 -0.037897  0.264323  0.398430        0.151465
# 17     DA8  0.490702  0.015872  0.043943  0.691796       -0.074468
# 18   DA023  0.864820 -0.003669  0.149771  0.081583        0.060870
#
#     decisionRegret                                    model_id  bdi Depression
# 0         0.097910  GambleEV_RPE_decisionRelief_decisionRegret   14    Low BDI
# 1         0.062707  GambleEV_RPE_decisionRelief_decisionRegret    8    Low BDI
# 2         0.163696  GambleEV_RPE_decisionRelief_decisionRegret   16    Low BDI
# 3        -0.005263  GambleEV_RPE_decisionRelief_decisionRegret   13    Low BDI
# 4         0.256731  GambleEV_RPE_decisionRelief_decisionRegret   26   High BDI
# 5         0.386541  GambleEV_RPE_decisionRelief_decisionRegret   26   High BDI
# 6         0.073964  GambleEV_RPE_decisionRelief_decisionRegret   12    Low BDI
# 7         0.029069  GambleEV_RPE_decisionRelief_decisionRegret   10    Low BDI
# 8        -0.037543  GambleEV_RPE_decisionRelief_decisionRegret   16    Low BDI
# 9         0.106369  GambleEV_RPE_decisionRelief_decisionRegret   10    Low BDI
# 10       -0.246735  GambleEV_RPE_decisionRelief_decisionRegret    9    Low BDI
# 11        0.100046  GambleEV_RPE_decisionRelief_decisionRegret   22   High BDI
# 12        0.221616  GambleEV_RPE_decisionRelief_decisionRegret   32   High BDI
# 13        0.253713  GambleEV_RPE_decisionRelief_decisionRegret   39   High BDI
# 14        0.160263  GambleEV_RPE_decisionRelief_decisionRegret   15    Low BDI
# 15        0.210786  GambleEV_RPE_decisionRelief_decisionRegret   10    Low BDI
# 16        0.297766  GambleEV_RPE_decisionRelief_decisionRegret   23   High BDI
# 17        0.199811  GambleEV_RPE_decisionRelief_decisionRegret   13    Low BDI
# 18        0.043193  GambleEV_RPE_decisionRelief_decisionRegret   14    Low BDI

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(25,5))
sns.set_theme(style='ticks',font='Arial') 
sns.boxplot(ax=ax1,data=depression_weights_plot, x='Depression',y='GambleEV',order=["High BDI", "Low BDI"],palette='BuGn_r')
sns.boxplot(ax=ax2,data=depression_weights_plot, x='Depression',y='RPE',order=["High BDI", "Low BDI"],palette='RdPu_r')
sns.boxplot(ax=ax3,data=depression_weights_plot, x='Depression',y='decisionRelief',order=["High BDI", "Low BDI"],palette='PuBu_r')
sns.boxplot(ax=ax4,data=depression_weights_plot, x='Depression',y='decisionRegret',order=["High BDI", "Low BDI"],palette='Oranges_r')

#ax1.set_ylim(-0.2,0.2)
ax1.set_ylabel('Regressor Weights',x=0.02,weight='medium',fontsize=16)
ax1.set_xlabel(None)
ax1.tick_params(labelsize=12)
r1,p1= spearmanr(depression_weights_plot.bdi,depression_weights_plot.GambleEV)
ax1.set_title(f'EV Spearman R:{np.round(r1,3)} P:{np.round(p1,3)}',weight='medium',fontsize=18)

#ax2.set_ylim(-0.1,0.6)
ax2.set_ylabel('Regressor Weights',x=0.02,weight='medium',fontsize=16)
ax2.set_xlabel(None)
ax2.tick_params(labelsize=12)
r2,p2= spearmanr(depression_weights_plot.bdi,depression_weights_plot.RPE)
ax2.set_title( f'RPE Spearman R:{np.round(r2,3)} P:{np.round(p2,3)}',weight='medium',fontsize=18)

#ax2.set_ylim(-0.1,0.6)
ax3.set_ylabel('Regressor Weights',x=0.02,weight='medium',fontsize=16)
ax3.set_xlabel(None)
ax3.tick_params(labelsize=12)
r3,p3= spearmanr(depression_weights_plot.bdi,depression_weights_plot.decisionRelief)
ax3.set_title(f'Relief Spearman R:{np.round(r3,3)} P:{np.round(p3,3)}',weight='medium',fontsize=18)

#ax2.set_ylim(-0.1,0.6)
ax4.set_ylabel('Regressor Weights',x=0.02,weight='medium',fontsize=16)
ax4.set_xlabel(None)
ax4.tick_params(labelsize=12)
r4,p4= spearmanr(depression_weights_plot.bdi,depression_weights_plot.decisionRegret)
ax4.set_title(f'Regret Spearman R:{np.round(r4,3)} P:{np.round(p4,3)}',weight='medium',fontsize=18)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Text(0.5, 1.0, 'Regret Spearman R:0.643 P:0.003')
